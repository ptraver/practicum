# %% [markdown]
# # This book is identical to RNN_soybean_weekly_weather.ipynb, except for the generation of test set predictions after validation set predictions

# %% [markdown]
# ### CONTENTS
# ### 1 Imports
# ### 2 Arrange datasets
# ### 3 Define models
# ### 4 Train models

# %% [markdown]
# # 1 Imports

# %%
# RNN imports

import tensorflow as tf

from keras.preprocessing.sequence import TimeseriesGenerator

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN

from keras.models import load_model

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
#General imports

import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import matplotlib.dates

from datetime import datetime

from google.colab import drive
import json

# %%
# Import weekly data

data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_weekly.csv'
soybean_df = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# fix bad name
soybean_df.columns = ['value']

# take only 1974 - 2017
soybean_df = soybean_df['1974-01-01':'2017-12-31']

# soybean_df needs to lose last value becuase during process of VMD, the last value is lost
soybean_df = soybean_df[:-1]

# view loaded data
soybean_df.tail(2)
# Out:
#             value
# date
# 2017-12-10  997.8
# 2017-12-17  974.3

# %%
# Import weather sets
data_url = 'https://raw.githubusercontent.com/ptraver/data/main/iowa_weather_train.csv'
iowa_weather_train = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='DATE')

data_url = 'https://raw.githubusercontent.com/ptraver/data/main/iowa_weather_valid.csv'
iowa_weather_valid = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='DATE')

data_url = 'https://raw.githubusercontent.com/ptraver/data/main/iowa_weather_test.csv'
iowa_weather_test = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='DATE')

# %% [markdown]
# # 2 Arrange datasets

# %%
# Split data so that valid and test do not feature in decisions
from sklearn.model_selection import train_test_split

true_train_split, out_of_sample = train_test_split(soybean_df, test_size=0.2, shuffle=False)
true_valid_split, true_test_split = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

# %%
# Scale data between 0 and 1
from sklearn.preprocessing import MinMaxScaler

true_scaler = MinMaxScaler()
true_train_scaled = true_scaler.fit_transform(true_train_split)
true_valid_scaled = true_scaler.transform(true_valid_split)
true_test_scaled = true_scaler.transform(true_test_split)

# %%
true_train = pd.DataFrame(true_train_scaled, columns=true_train_split.columns, index=true_train_split.index)
true_valid = pd.DataFrame(true_valid_scaled, columns=true_valid_split.columns, index=true_valid_split.index)
true_test = pd.DataFrame(true_test_scaled, columns=true_test_split.columns, index=true_test_split.index)

# %%
# Double-check that indices are equal
print(true_train.index.equals(iowa_weather_train.index))
print(true_valid.index.equals(iowa_weather_valid.index))
print(true_test.index.equals(iowa_weather_test.index))
# Out:
# True
# True
# True

# %%
# Join weather and price data
train_weather = true_train.join(iowa_weather_train)
valid_weather = true_valid.join(iowa_weather_valid)
test_weather = true_test.join(iowa_weather_test)

# %%
# Set input shape variable
n_inputs = 4

# %%
# Get sets in order
train_shaped = TimeseriesGenerator(train_weather, true_train.values, length=n_inputs, batch_size=1)
valid_shaped = TimeseriesGenerator(valid_weather, true_valid.values, length=n_inputs, batch_size=1)
test_shaped = TimeseriesGenerator(test_weather, true_test.values, length=n_inputs, batch_size=1)

# %% [markdown]
# # 3 Define models

# %%
# Set shape variables
L1_units = 8
L2_units = 12
L3_units = 8

# Set number of features
n_features = 4

# %%
# Set other variables
activation = 'relu'
dropout = 0
optimizer = 'adam'
loss = 'mse'

# %%
# Define vmd model definition function

def define_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=L1_units, input_shape=(n_inputs, n_features), activation=activation, dropout=dropout, return_sequences=True))
  RNNregressor.add(SimpleRNN(units=L2_units, input_shape=(n_inputs, n_features), activation=activation, dropout=dropout, return_sequences=True))
  RNNregressor.add(SimpleRNN(units=L3_units, input_shape=(n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %% [markdown]
# # 4 Train models

# %%
# Set variables
EPOCHS = 50

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Set checkpoint callback
filepath = 'true_RNN_weather_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
RNNregressor = define_model()

# Train model
with tf.device('/device:GPU:0'):
  RNNregressor.fit(train_shaped,
                   epochs=EPOCHS,
                   validation_data=valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 0.0209INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_01.model/assets
# 1831/1831 [==============================] - 17s 8ms/step - loss: 0.0209 - val_loss: 0.2353
# Epoch 2/50
# 1831/1831 [==============================] - ETA: 0s - loss: 0.0119INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_02.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 0.0119 - val_loss: 0.1464
# Epoch 3/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 0.0089INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_03.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 0.0089 - val_loss: 0.0858
# Epoch 4/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 0.0045INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_04.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 0.0045 - val_loss: 0.0457
# Epoch 5/50
# 1820/1831 [============================>.] - ETA: 0s - loss: 0.0027INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_05.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 0.0027 - val_loss: 0.0579
# Epoch 6/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 0.0022INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_06.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 0.0022 - val_loss: 0.0353
# Epoch 7/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 0.0017INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_07.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 0.0017 - val_loss: 0.0316
# Epoch 8/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 0.0013INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_08.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0213
# Epoch 9/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 0.0011INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_09.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0174
# Epoch 10/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 9.6615e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_10.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 9.6315e-04 - val_loss: 0.0158
# Epoch 11/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 8.8731e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_11.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 8.8742e-04 - val_loss: 0.0088
# Epoch 12/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 7.9906e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_12.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 8.0026e-04 - val_loss: 0.0070
# Epoch 13/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 7.3388e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_13.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 7.3551e-04 - val_loss: 0.0062
# Epoch 14/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 5.7652e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_14.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 5.7486e-04 - val_loss: 0.0102
# Epoch 15/50
# 1822/1831 [============================>.] - ETA: 0s - loss: 5.9203e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_15.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 6.0791e-04 - val_loss: 0.0045
# Epoch 16/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 5.5971e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_16.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 5.5944e-04 - val_loss: 0.0033
# Epoch 17/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 5.4348e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_17.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 5.4118e-04 - val_loss: 0.0018
# Epoch 18/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 4.9104e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_18.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 4.9078e-04 - val_loss: 0.0022
# Epoch 19/50
# 1831/1831 [==============================] - ETA: 0s - loss: 4.9568e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_19.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.9568e-04 - val_loss: 0.0054
# Epoch 20/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 4.9406e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_20.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 4.9434e-04 - val_loss: 0.0021
# Epoch 21/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 5.0681e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_21.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 5.0544e-04 - val_loss: 0.0025
# Epoch 22/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.9527e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_22.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.9494e-04 - val_loss: 0.0023
# Epoch 23/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.6817e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_23.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.6678e-04 - val_loss: 0.0088
# Epoch 24/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 4.9390e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_24.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.9384e-04 - val_loss: 0.0064
# Epoch 25/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 4.5220e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_25.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.5141e-04 - val_loss: 0.0025
# Epoch 26/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 4.5046e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_26.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.5052e-04 - val_loss: 0.0018
# Epoch 27/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 4.6256e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_27.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.6249e-04 - val_loss: 0.0065
# Epoch 28/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 4.4081e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_28.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.4062e-04 - val_loss: 0.0038
# Epoch 29/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 4.7467e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_29.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.8750e-04 - val_loss: 0.0073
# Epoch 30/50
# 1831/1831 [==============================] - ETA: 0s - loss: 4.5605e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_30.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.5605e-04 - val_loss: 0.0033
# Epoch 31/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 4.5616e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_31.model/assets
# 1831/1831 [==============================] - 16s 8ms/step - loss: 4.5604e-04 - val_loss: 0.0022
# Epoch 32/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.3166e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_32.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.3643e-04 - val_loss: 0.0030
# Epoch 33/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 4.3779e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_33.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.4516e-04 - val_loss: 0.0029
# Epoch 34/50
# 1822/1831 [============================>.] - ETA: 0s - loss: 4.2461e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_34.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 4.2500e-04 - val_loss: 0.0030
# Epoch 35/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.3053e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_35.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.2955e-04 - val_loss: 0.0025
# Epoch 36/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 4.3036e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_36.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 4.2983e-04 - val_loss: 0.0027
# Epoch 37/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 4.5396e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_37.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.5282e-04 - val_loss: 0.0026
# Epoch 38/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 4.3771e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_38.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.3673e-04 - val_loss: 0.0028
# Epoch 39/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 4.2140e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_39.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 4.2173e-04 - val_loss: 0.0018
# Epoch 40/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 4.3792e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_40.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.3646e-04 - val_loss: 0.0019
# Epoch 41/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.2450e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_41.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.2444e-04 - val_loss: 0.0035
# Epoch 42/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 3.9617e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_42.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 3.9577e-04 - val_loss: 0.0044
# Epoch 43/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 4.2609e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_43.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.2476e-04 - val_loss: 0.0033
# Epoch 44/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.3378e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_44.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 4.3409e-04 - val_loss: 0.0030
# Epoch 45/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 4.2740e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_45.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.2680e-04 - val_loss: 0.0025
# Epoch 46/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 4.3488e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_46.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 4.3434e-04 - val_loss: 0.0036
# Epoch 47/50
# 1831/1831 [==============================] - ETA: 0s - loss: 4.2929e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_47.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.2929e-04 - val_loss: 0.0021
# Epoch 48/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 4.1733e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_48.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.1657e-04 - val_loss: 0.0043
# Epoch 49/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 4.0847e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_49.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 4.0743e-04 - val_loss: 0.0054
# Epoch 50/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 4.3062e-04INFO:tensorflow:Assets written to: models/true_RNN_weather_valid_50.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 4.3065e-04 - val_loss: 0.0030

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'true_RNN_weather_valid_24'

# %%
# Save best model to Drive
true_RNN_weather_model = load_model(f'models/{best_model}.model')
true_RNN_weather_model.save(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
true_fc = true_RNN_weather_model.predict(valid_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/true_RNN_weather_valid.npy', true_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
true_RNN_weather_model = load_model(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
true_fc = true_RNN_weather_model.predict(test_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/true_RNN_weather_test.npy', true_rescaled.flatten())

# %% [markdown]
# # End
