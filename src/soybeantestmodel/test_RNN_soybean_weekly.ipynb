# %% [markdown]
# # This book is identical to RNN_soybean_weekly.ipynb, except for the generation of test set predictions after validation set predictions

# %% [markdown]
# ### CONTENTS
# ### 1 Imports
# ### 2 Arrange datasets
# ### 3 Define models
# ### 4 Train models

# %% [markdown]
# # 1 Imports

# %%
# RNN imports

import tensorflow as tf

from keras.preprocessing.sequence import TimeseriesGenerator

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN

from keras.models import load_model

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
#General imports

import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import matplotlib.dates

from datetime import datetime

from google.colab import drive
import json

# %%
# Import weekly data

data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_weekly.csv'
soybean_df = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# fix bad name
soybean_df.columns = ['value']

# take only 1974 - 2017
soybean_df = soybean_df['1974-01-01':'2017-12-31']

# soybean_df needs to lose last value becuase during process of VMD, the last value is lost
soybean_df = soybean_df[:-1]

# view loaded data
soybean_df.tail(2)
# Out:
#             value
# date
# 2017-12-10  997.8
# 2017-12-17  974.3

# %%
# Import emd data
data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_emd_weekly.csv'
soybean_emd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Import vmd data
data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_vmd_weekly.csv'
soybean_vmd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Check indices are aligned
print(soybean_df.index.equals(soybean_emd.index))
print(soybean_df.index.equals(soybean_vmd.index))
# Out:
# True
# True

# %% [markdown]
# # 2 Arrange datasets

# %%
# Split data so that valid and test do not feature in decisions
from sklearn.model_selection import train_test_split

true_train, out_of_sample = train_test_split(soybean_df, test_size=0.2, shuffle=False)
true_valid, true_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

emd_train, out_of_sample = train_test_split(soybean_emd, test_size=0.2, shuffle=False)
emd_valid, emd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

vmd_train, out_of_sample = train_test_split(soybean_vmd, test_size=0.2, shuffle=False)
vmd_valid, vmd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

# %%
# Scale data between 0 and 1
from sklearn.preprocessing import MinMaxScaler

emd_scaler = MinMaxScaler()
emd_train = emd_scaler.fit_transform(emd_train)
emd_valid = emd_scaler.transform(emd_valid)
emd_test = emd_scaler.transform(emd_test)

vmd_scaler = MinMaxScaler()
vmd_train = vmd_scaler.fit_transform(vmd_train)
vmd_valid = vmd_scaler.transform(vmd_valid)
vmd_test = vmd_scaler.transform(vmd_test)

true_scaler = MinMaxScaler()
true_train = true_scaler.fit_transform(true_train)
true_valid = true_scaler.transform(true_valid)
true_test = true_scaler.transform(true_test)

# %%
# Set input shape variables
emd_n_inputs = 4
vmd_n_inputs = 5
non_decomp_n_inputs = 5

# %%
# get emd sets in order
emd_extra_valid = emd_train[-emd_n_inputs:]
emd_valid_set = np.concatenate((emd_extra_valid, emd_valid))

emd_extra_test = emd_valid[-emd_n_inputs:]
emd_test_set = np.concatenate((emd_extra_test, emd_test))

emd_train_shaped = TimeseriesGenerator(emd_train, emd_train, length=emd_n_inputs, batch_size=1)
emd_valid_shaped = TimeseriesGenerator(emd_valid_set, emd_valid_set, length=emd_n_inputs, batch_size=1)
emd_test_shaped = TimeseriesGenerator(emd_test_set, emd_test_set, length=emd_n_inputs, batch_size=1)

# %%
# get vmd sets in order
vmd_extra_valid = vmd_train[-vmd_n_inputs:]
vmd_valid_set = np.concatenate((vmd_extra_valid, vmd_valid))

vmd_extra_test = vmd_valid[-vmd_n_inputs:]
vmd_test_set = np.concatenate((vmd_extra_test, vmd_test))

vmd_train_shaped = TimeseriesGenerator(vmd_train, vmd_train, length=vmd_n_inputs, batch_size=1)
vmd_valid_shaped = TimeseriesGenerator(vmd_valid_set, vmd_valid_set, length=vmd_n_inputs, batch_size=1)
vmd_test_shaped = TimeseriesGenerator(vmd_test_set, vmd_test_set, length=vmd_n_inputs, batch_size=1)

# %%
# get non-decomposed sets in order
extra_valid = true_train[-non_decomp_n_inputs:]
valid_set = np.concatenate((extra_valid, true_valid))

extra_test = true_valid[-non_decomp_n_inputs:]
test_set = np.concatenate((extra_test, true_test))

train_shaped = TimeseriesGenerator(true_train, true_train, length=non_decomp_n_inputs, batch_size=1)
valid_shaped = TimeseriesGenerator(valid_set, valid_set, length=non_decomp_n_inputs, batch_size=1)
test_shaped = TimeseriesGenerator(test_set, test_set, length=non_decomp_n_inputs, batch_size=1)

# %% [markdown]
# # 3 Define models

# %%
# Set shape variables
emd_units = 7

vmd_L1_units = 7
vmd_L2_units = 4

non_decomp_units = 7

# Set number of features
n_features = 1

# %%
# Set other variables
activation = 'relu'
dropout = 0
optimizer = 'adam'
loss = 'mse'

# %%
# Define emd model definition function

def define_emd_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=emd_units, input_shape=(emd_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %%
# Define vmd model definition function

def define_vmd_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=vmd_L1_units, input_shape=(vmd_n_inputs, n_features), activation=activation, dropout=dropout, return_sequences=True))
  RNNregressor.add(SimpleRNN(units=vmd_L2_units, input_shape=(vmd_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %%
# Define non decomp model definition function

def define_non_decomp_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=non_decomp_units, input_shape=(non_decomp_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %% [markdown]
# # 4 Train models

# %%
# Set variables

decomp_EPOCHS = 50
non_decomp_EPOCHS = 8

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###on EMD soybean weekly

# %%
# Set checkpoint callback
filepath = 'emd_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
EMDregressor = define_emd_model()

# Train model
with tf.device('/device:GPU:0'):
  EMDregressor.fit(emd_train_shaped,
                   epochs=decomp_EPOCHS,
                   validation_data=emd_valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 0.0091INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_01.model/assets
# 1831/1831 [==============================] - 14s 6ms/step - loss: 0.0091 - val_loss: 0.0047
# Epoch 2/50
# 1831/1831 [==============================] - ETA: 0s - loss: 7.0068e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_02.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 7.0068e-04 - val_loss: 0.0029
# Epoch 3/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 6.0045e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_03.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 5.9991e-04 - val_loss: 0.0017
# Epoch 4/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 5.5681e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_04.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 5.5651e-04 - val_loss: 0.0014
# Epoch 5/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 5.2414e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_05.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 5.2527e-04 - val_loss: 8.9025e-04
# Epoch 6/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 4.9232e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_06.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 4.9340e-04 - val_loss: 0.0015
# Epoch 7/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 4.7329e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_07.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 4.7216e-04 - val_loss: 0.0012
# Epoch 8/50
# 1831/1831 [==============================] - ETA: 0s - loss: 4.4888e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_08.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 4.4888e-04 - val_loss: 8.7608e-04
# Epoch 9/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 4.2717e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_09.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 4.2696e-04 - val_loss: 7.1612e-04
# Epoch 10/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 4.0716e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_10.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 4.0643e-04 - val_loss: 0.0011
# Epoch 11/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 3.8123e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_11.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 3.8046e-04 - val_loss: 7.9215e-04
# Epoch 12/50
# 1831/1831 [==============================] - ETA: 0s - loss: 3.6404e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_12.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 3.6404e-04 - val_loss: 7.4861e-04
# Epoch 13/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 3.4201e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_13.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 3.4164e-04 - val_loss: 6.8449e-04
# Epoch 14/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 3.0809e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_14.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 3.0756e-04 - val_loss: 6.2897e-04
# Epoch 15/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 3.0096e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_15.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.9978e-04 - val_loss: 0.0019
# Epoch 16/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 2.7497e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_16.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.7476e-04 - val_loss: 4.7298e-04
# Epoch 17/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 2.6108e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_17.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.6096e-04 - val_loss: 8.9408e-04
# Epoch 18/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 2.4860e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_18.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.4842e-04 - val_loss: 4.5079e-04
# Epoch 19/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 2.2698e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_19.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.2744e-04 - val_loss: 7.0160e-04
# Epoch 20/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 2.1512e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_20.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.1519e-04 - val_loss: 6.9410e-04
# Epoch 21/50
# 1821/1831 [============================>.] - ETA: 0s - loss: 2.0472e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_21.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 2.0494e-04 - val_loss: 5.0357e-04
# Epoch 22/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 1.9019e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_22.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.9009e-04 - val_loss: 6.9581e-04
# Epoch 23/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 1.8032e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_23.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.8035e-04 - val_loss: 3.1815e-04
# Epoch 24/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 1.7293e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_24.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.7293e-04 - val_loss: 6.9200e-04
# Epoch 25/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 1.6710e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_25.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.6691e-04 - val_loss: 4.1464e-04
# Epoch 26/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 1.6258e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_26.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.6238e-04 - val_loss: 3.6589e-04
# Epoch 27/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 1.5432e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_27.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.5412e-04 - val_loss: 3.3788e-04
# Epoch 28/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 1.5069e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_28.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.5051e-04 - val_loss: 2.8948e-04
# Epoch 29/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 1.3601e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_29.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.3594e-04 - val_loss: 2.4906e-04
# Epoch 30/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 1.3452e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_30.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.3405e-04 - val_loss: 3.3225e-04
# Epoch 31/50
# 1831/1831 [==============================] - ETA: 0s - loss: 1.2772e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_31.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.2772e-04 - val_loss: 2.2014e-04
# Epoch 32/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 1.2371e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_32.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.2441e-04 - val_loss: 2.1019e-04
# Epoch 33/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 1.1637e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_33.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.1677e-04 - val_loss: 4.3138e-04
# Epoch 34/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 1.1080e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_34.model/assets
# 1831/1831 [==============================] - 12s 6ms/step - loss: 1.1085e-04 - val_loss: 1.9451e-04
# Epoch 35/50
# 1822/1831 [============================>.] - ETA: 0s - loss: 1.0732e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_35.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.0797e-04 - val_loss: 1.8783e-04
# Epoch 36/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 1.0313e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_36.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.0301e-04 - val_loss: 2.3957e-04
# Epoch 37/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 1.0043e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_37.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 1.0047e-04 - val_loss: 2.6560e-04
# Epoch 38/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 9.5143e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_38.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 9.4889e-05 - val_loss: 1.6458e-04
# Epoch 39/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 8.7663e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_39.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 8.7473e-05 - val_loss: 1.5139e-04
# Epoch 40/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 8.4063e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_40.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 8.4033e-05 - val_loss: 2.0214e-04
# Epoch 41/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 8.1512e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_41.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 8.1570e-05 - val_loss: 2.4756e-04
# Epoch 42/50
# 1831/1831 [==============================] - ETA: 0s - loss: 7.6186e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_42.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 7.6186e-05 - val_loss: 3.1674e-04
# Epoch 43/50
# 1831/1831 [==============================] - ETA: 0s - loss: 7.2165e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_43.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 7.2165e-05 - val_loss: 1.1829e-04
# Epoch 44/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 6.7491e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_44.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 6.7476e-05 - val_loss: 1.2160e-04
# Epoch 45/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 6.7741e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_45.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 6.7606e-05 - val_loss: 1.3919e-04
# Epoch 46/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 6.4091e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_46.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 6.4127e-05 - val_loss: 1.9991e-04
# Epoch 47/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 6.3281e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_47.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 6.3252e-05 - val_loss: 1.8123e-04
# Epoch 48/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 6.0855e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_48.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 6.0638e-05 - val_loss: 1.3258e-04
# Epoch 49/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 5.7109e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_49.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 5.7228e-05 - val_loss: 6.9541e-04
# Epoch 50/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 5.5150e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_50.model/assets
# 1831/1831 [==============================] - 11s 6ms/step - loss: 5.5000e-05 - val_loss: 1.1922e-04

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'emd_RNN_weekly_valid_46'

# %%
# Save best model to Drive
emd_RNN_weekly_model = load_model(f'models/{best_model}.model')
emd_RNN_weekly_model.save(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
emd_fc = emd_RNN_weekly_model.predict(emd_valid_shaped)

# %%
# Rescale forecasted values
emd_rescaled = emd_scaler.inverse_transform(emd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/emd_RNN_weekly_valid.npy', emd_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
emd_RNN_weekly_model = load_model(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
emd_fc = emd_RNN_weekly_model.predict(emd_test_shaped)

# %%
# Rescale forecasted values
emd_rescaled = emd_scaler.inverse_transform(emd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/emd_RNN_weekly_test.npy', emd_rescaled.flatten())

# %% [markdown]
# ###on VMD soybean weekly

# %%
# Set checkpoint callback
filepath = 'vmd_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
VMDregressor = define_vmd_model()

# Train model
with tf.device('/device:GPU:0'):
  VMDregressor.fit(vmd_train_shaped,
                   epochs=decomp_EPOCHS,
                   validation_data=vmd_valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 3.1124e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_01.model/assets
# 1830/1830 [==============================] - 24s 12ms/step - loss: 3.1075e-04 - val_loss: 2.9572e-04
# Epoch 2/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.8163e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_02.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.8156e-04 - val_loss: 3.0734e-04
# Epoch 3/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.1948e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_03.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.1927e-04 - val_loss: 3.4441e-04
# Epoch 4/50
# 1830/1830 [==============================] - ETA: 0s - loss: 9.6828e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_04.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 9.6828e-05 - val_loss: 2.1928e-04
# Epoch 5/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 5.9817e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_05.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 5.9748e-05 - val_loss: 6.0230e-05
# Epoch 6/50
# 1830/1830 [==============================] - ETA: 0s - loss: 6.0733e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_06.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 6.0733e-05 - val_loss: 5.2096e-05
# Epoch 7/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 4.6219e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_07.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 4.6163e-05 - val_loss: 8.0684e-05
# Epoch 8/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 4.6647e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_08.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 4.6604e-05 - val_loss: 4.7579e-05
# Epoch 9/50
# 1830/1830 [==============================] - ETA: 0s - loss: 4.1174e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_09.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 4.1174e-05 - val_loss: 2.8718e-05
# Epoch 10/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 3.6687e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_10.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 3.6668e-05 - val_loss: 2.4247e-05
# Epoch 11/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 3.1455e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_11.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 3.1430e-05 - val_loss: 7.5134e-05
# Epoch 12/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.9441e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_12.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 2.9402e-05 - val_loss: 2.1680e-05
# Epoch 13/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 3.6586e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_13.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 3.6568e-05 - val_loss: 4.2618e-05
# Epoch 14/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.6900e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_14.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 2.6846e-05 - val_loss: 6.7337e-05
# Epoch 15/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 2.9363e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_15.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 2.9329e-05 - val_loss: 9.0086e-05
# Epoch 16/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 2.8139e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_16.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 2.8192e-05 - val_loss: 4.8311e-05
# Epoch 17/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.0642e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_17.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 2.0737e-05 - val_loss: 2.1395e-04
# Epoch 18/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.2586e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_18.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 2.2567e-05 - val_loss: 1.8752e-05
# Epoch 19/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.6764e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_19.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.6791e-05 - val_loss: 1.3787e-04
# Epoch 20/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 2.0508e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_20.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 2.0483e-05 - val_loss: 3.2334e-05
# Epoch 21/50
# 1830/1830 [==============================] - ETA: 0s - loss: 1.8989e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_21.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.8989e-05 - val_loss: 4.9513e-04
# Epoch 22/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.4990e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_22.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.4982e-05 - val_loss: 8.2908e-05
# Epoch 23/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.1093e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_23.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 2.1088e-05 - val_loss: 5.3490e-05
# Epoch 24/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.4553e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_24.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.4664e-05 - val_loss: 1.5730e-05
# Epoch 25/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.4144e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_25.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.4139e-05 - val_loss: 3.4492e-05
# Epoch 26/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.1010e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_26.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 2.1046e-05 - val_loss: 6.2197e-05
# Epoch 27/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.3572e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_27.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.3544e-05 - val_loss: 6.2332e-05
# Epoch 28/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.7201e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_28.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.7226e-05 - val_loss: 1.8999e-04
# Epoch 29/50
# 1825/1830 [============================>.] - ETA: 0s - loss: 1.4918e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_29.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.4890e-05 - val_loss: 2.3485e-04
# Epoch 30/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.7172e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_30.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.7156e-05 - val_loss: 2.1959e-05
# Epoch 31/50
# 1830/1830 [==============================] - ETA: 0s - loss: 1.5873e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_31.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.5873e-05 - val_loss: 3.1162e-05
# Epoch 32/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.6594e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_32.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.6587e-05 - val_loss: 1.4580e-05
# Epoch 33/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.6114e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_33.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.6105e-05 - val_loss: 4.1308e-05
# Epoch 34/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.4661e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_34.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.4638e-05 - val_loss: 5.2106e-05
# Epoch 35/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.3402e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_35.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.3398e-05 - val_loss: 3.5112e-05
# Epoch 36/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.4123e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_36.model/assets
# 1830/1830 [==============================] - 22s 12ms/step - loss: 1.4120e-05 - val_loss: 1.1014e-05
# Epoch 37/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.7351e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_37.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.7344e-05 - val_loss: 3.5161e-05
# Epoch 38/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.1820e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_38.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.1810e-05 - val_loss: 1.2935e-05
# Epoch 39/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.5621e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_39.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.5613e-05 - val_loss: 3.3848e-05
# Epoch 40/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.4008e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_40.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.4005e-05 - val_loss: 4.2892e-05
# Epoch 41/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.3937e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_41.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.3931e-05 - val_loss: 1.0787e-04
# Epoch 42/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.3130e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_42.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.3115e-05 - val_loss: 1.2928e-05
# Epoch 43/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.5351e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_43.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.5340e-05 - val_loss: 6.1770e-05
# Epoch 44/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.4120e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_44.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.4093e-05 - val_loss: 6.5068e-05
# Epoch 45/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.4461e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_45.model/assets
# 1830/1830 [==============================] - 23s 12ms/step - loss: 1.4456e-05 - val_loss: 3.1713e-05
# Epoch 46/50
# 1830/1830 [==============================] - ETA: 0s - loss: 1.3216e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_46.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.3216e-05 - val_loss: 4.7926e-05
# Epoch 47/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.5032e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_47.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 1.5026e-05 - val_loss: 1.0844e-05
# Epoch 48/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.6261e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_48.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.6254e-05 - val_loss: 3.1394e-04
# Epoch 49/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.2363e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_49.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.2345e-05 - val_loss: 6.4765e-05
# Epoch 50/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.9061e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_50.model/assets
# 1830/1830 [==============================] - 23s 13ms/step - loss: 1.9074e-05 - val_loss: 5.8555e-05

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'vmd_RNN_weekly_valid_38'

# %%
# Save best model to Drive
vmd_RNN_weekly_model = load_model(f'models/{best_model}.model')
vmd_RNN_weekly_model.save(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
vmd_fc = vmd_RNN_weekly_model.predict(vmd_valid_shaped)

# %%
# Rescale forecasted values
vmd_rescaled = vmd_scaler.inverse_transform(vmd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/vmd_RNN_weekly_valid.npy', vmd_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
vmd_RNN_weekly_model = load_model(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
vmd_fc = vmd_RNN_weekly_model.predict(vmd_test_shaped)

# %%
# Rescale forecasted values
vmd_rescaled = vmd_scaler.inverse_transform(vmd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/vmd_RNN_weekly_test.npy', vmd_rescaled.flatten())

# %% [markdown]
# ## on non-decomposed

# %%
# Set checkpoint callback
filepath = 'true_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
TRUEregressor = define_non_decomp_model()

# Train model
with tf.device('/device:GPU:0'):
  TRUEregressor.fit(train_shaped,
                   epochs=non_decomp_EPOCHS,
                   validation_data=valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/8
# 1825/1830 [============================>.] - ETA: 0s - loss: 0.0025INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_01.model/assets
# 1830/1830 [==============================] - 14s 7ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 2/8
# 1826/1830 [============================>.] - ETA: 0s - loss: 8.0238e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_02.model/assets
# 1830/1830 [==============================] - 12s 7ms/step - loss: 8.0339e-04 - val_loss: 0.0036
# Epoch 3/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 6.4634e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_03.model/assets
# 1830/1830 [==============================] - 12s 7ms/step - loss: 6.4686e-04 - val_loss: 0.0015
# Epoch 4/8
# 1829/1830 [============================>.] - ETA: 0s - loss: 5.6690e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_04.model/assets
# 1830/1830 [==============================] - 12s 7ms/step - loss: 5.6659e-04 - val_loss: 0.0023
# Epoch 5/8
# 1827/1830 [============================>.] - ETA: 0s - loss: 4.9299e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_05.model/assets
# 1830/1830 [==============================] - 13s 7ms/step - loss: 4.9276e-04 - val_loss: 0.0011
# Epoch 6/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 4.4836e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_06.model/assets
# 1830/1830 [==============================] - 13s 7ms/step - loss: 4.5119e-04 - val_loss: 0.0010
# Epoch 7/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 4.2661e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_07.model/assets
# 1830/1830 [==============================] - 12s 7ms/step - loss: 4.2544e-04 - val_loss: 0.0013
# Epoch 8/8
# 1829/1830 [============================>.] - ETA: 0s - loss: 4.2074e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_08.model/assets
# 1830/1830 [==============================] - 14s 7ms/step - loss: 4.2059e-04 - val_loss: 0.0024

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'true_RNN_weekly_valid_05'

# %%
# Save best model to Drive
true_RNN_weekly_model = load_model(f'models/{best_model}.model')
true_RNN_weekly_model.save(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
true_fc = true_RNN_weekly_model.predict(valid_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/true_RNN_weekly_valid.npy', true_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
true_RNN_weekly_model = load_model(f'/content/gdrive/MyDrive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
true_fc = true_RNN_weekly_model.predict(test_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/MyDrive/outputs/test/daily/true_RNN_weekly_test.npy', true_rescaled.flatten())

# %% [markdown]
# # End
