# %% [markdown]
# # This book is identical to ARIMA_soybean_weekly.ipynb, except the addition of section 11 Generate test set predictions

# %% [markdown]
# ### CONTENTS
# ### 1 Installations and imports
# ### 2 Check stationarity assumption
# ### 3 Visualise ACF and PACF plots for single-differenced series
# ### 4 Investigate single-differenced non-seasonal model order
# ### 5 Investigate single-differenced seasonal model order (only relevant for vmd)
# ### 6 Expand search around most promising seasonal orders
# ### 7 Check stationarity assumption of seasonal differencing
# ### 8 Visualise ACF and PACF plots for seasonally-differenced series
# ### 9 Investigate seasonally-differenced model order
# ### 10 Generate validation set predictions
# ### 11 Generate test set predictions

# %% [markdown]
# # 1 Installations and imports

# %%
# ARIMA installations

# !pip install pmdarima
# !pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.13.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)

# %%
# ARIMA imports

from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm #Auto arima
from statsmodels.tsa.stattools import acf #Metrics
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
#General imports

import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import matplotlib.dates

from datetime import datetime

from google.colab import drive
import json

# %%
# Import daily data

data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_weekly.csv'
soybean_df = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# fix bad name
soybean_df.columns = ['value']

# take only 1974 - 2017
soybean_df = soybean_df['1974-01-01':'2017-12-31']

# soybean_df needs to lose last value becuase during process of VMD, the last value is lost
soybean_df = soybean_df[:-1]

# view loaded data
soybean_df.tail(2)
# Out:
#             value
# date
# 2017-12-10  997.8
# 2017-12-17  974.3

# %%
# Import emd data
data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_emd_weekly.csv'
soybean_emd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Import vmd data
data_url = 'https://raw.githubusercontent.com/kumars8/Deloitte_login_prjct/master/soybean_vmd_weekly.csv'
soybean_vmd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Check indices are aligned
print(soybean_df.index.equals(soybean_emd.index))
print(soybean_df.index.equals(soybean_vmd.index))
# Out:
# True
# True

# %%
# Split data so that valid and test do not feature in decisions
from sklearn.model_selection import train_test_split

true_train, out_of_sample = train_test_split(soybean_df, test_size=0.2, shuffle=False)
true_valid, true_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)
true_in = true_train.append(true_valid)

emd_train, out_of_sample = train_test_split(soybean_emd, test_size=0.2, shuffle=False)
emd_valid, emd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)
emd_in = emd_train.append(emd_valid)

vmd_train, out_of_sample = train_test_split(soybean_vmd, test_size=0.2, shuffle=False)
vmd_valid, vmd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)
vmd_in = vmd_train.append(vmd_valid)

# %% [markdown]
# # 2 Check stationarity assumption: does each series achieve stationarity with a single differencing?

# %%
# Non-differenced

# %%
# For non-decomposed, non-differenced fails stationarity test
result = adfuller(true_in['value'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -2.326658
# p-value: 0.163514

# %%
# EMD non-differenced fails stationarity test
result = adfuller(emd_in['value'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.976726
# p-value: 0.296870

# %%
# VMD non-differenced fails stationarity test
result = adfuller(vmd_in['value'].dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -2.295899
# p-value: 0.173294

# %%
# Differenced

# %%
# ADF non-decomposed differenced passes stationarity test
result = adfuller(true_in['value'].diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -14.097861
# p-value: 0.000000

# %%
# ADF EMD differenced passes stationarity test
result = adfuller(emd_in['value'].diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -9.967785
# p-value: 0.000000

# %%
# ADF VMD differenced passes stationarity test
result = adfuller(vmd_in['value'].diff().dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -7.882916
# p-value: 0.000000

# %% [markdown]
# # 3 Visualise ACF and PACF plots for single-differenced series

# %%
# ACF no decomp, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(true_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = true_in['value'].values
lags_n = 110
plot_acf(series_data, ax=axes[0, 1], lags=lags_n)

# 1st Differencing
axes[1, 0].plot(true_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = true_in['value'].diff().dropna().values
first_diff_lags_n = 110
plot_acf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n)

plt.show()

# %%
# PACF no decomp, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(true_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = true_in['value'].values
lags_n = 110
plot_pacf(series_data, ax=axes[0, 1], lags=lags_n, method='ywm')

# 1st Differencing
axes[1, 0].plot(true_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = true_in['value'].diff().dropna().values
first_diff_lags_n = 110
plot_pacf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n, method='ywm')

plt.show()

# %%
# Looks like p=1, q=1 at most
# ARIMA doesn't seem suitable for this series - non-decomposed investigations stop here

# %%
# ACF emd, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(emd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = emd_in['value'].values
lags_n = 110
plot_acf(series_data, ax=axes[0, 1], lags=lags_n)

# 1st Differencing
axes[1, 0].plot(emd_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = emd_in['value'].diff().dropna().values
first_diff_lags_n = 110
plot_acf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n)

plt.show()

# %%
# PACF emd, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(emd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = emd_in['value'].values
lags_n = 110
plot_pacf(series_data, ax=axes[0, 1], lags=lags_n, method='ywm')

# 1st Differencing
axes[1, 0].plot(emd_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = emd_in['value'].diff().dropna().values
first_diff_lags_n = 110
plot_pacf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n, method='ywm')

plt.show()

# %%
# Differenced ACF/PACF suggests could be as many as 3 autoregressive terms and 3 moving average terms

# Non-differenced PACF suggests maybe lag 4 differencing

# %%
# ACF vmd, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(vmd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = vmd_in['value'].values
lags_n = 110
plot_acf(series_data, ax=axes[0, 1], lags=lags_n)

# 1st Differencing
axes[1, 0].plot(vmd_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = vmd_in['value'].diff().dropna().values
first_diff_lags_n = 30
plot_acf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n)

plt.show()

# %%
# PACF vmd, 1 diff

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(vmd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = vmd_in['value'].values
lags_n = 110
plot_pacf(series_data, ax=axes[0, 1], lags=lags_n, method='ywm')

# 1st Differencing
axes[1, 0].plot(vmd_in['value'].diff().values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = vmd_in['value'].diff().dropna().values
first_diff_lags_n = 25
plot_pacf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n, method='ywm')

plt.show()

# %%
# Differenced ACF/PACF suggests p is as many as 3, q is as many as 2

# differenced ACF suggests trying seasonal with lag 8, 9, 10
# differenced PACF suggest trying seasonal with lag 4, 5, 6

# %% [markdown]
# # 4 Investigate single-differenced non-seasonal model order

# %%
# auto arima emd
emd_arima = pm.auto_arima(emd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=False,   # No Seasonality
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=6)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16996.541, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=14049.568, Time=0.50 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=14391.730, Time=1.38 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16996.366, Time=0.19 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=11834.139, Time=0.69 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=10649.084, Time=1.04 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=10189.290, Time=2.31 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=10500.597, Time=1.24 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=10174.370, Time=3.33 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=10215.107, Time=2.02 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=10174.665, Time=4.12 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=10179.838, Time=3.21 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=10172.652, Time=1.01 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=10213.534, Time=0.70 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=10187.523, Time=1.18 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=10172.915, Time=1.93 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=10499.230, Time=0.70 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=10178.181, Time=1.60 sec
#
# Best model:  ARIMA(3,1,2)(0,0,0)[0]
# Total fit time: 27.331 seconds

# %%
# auto arima vmd
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=1,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=False,   # No Seasonality
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=5)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16622.715, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=13191.621, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=14041.985, Time=1.28 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16622.672, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=10363.583, Time=0.64 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=9430.118, Time=0.88 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=9431.928, Time=2.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=9608.251, Time=1.39 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=9428.327, Time=0.53 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=10362.643, Time=0.48 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=9430.147, Time=1.25 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=9606.912, Time=0.58 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 9.819 seconds

# %% [markdown]
# # 5 Investigate single-differenced seasonal model order (only relevant for vmd)

# %%
# try vmd seasonal models with autoregressive lags 4,5,6 and moving average lags 8,9,10

# %%
# auto arima vmd, lag 4
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=4,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=1, max_P=3,
                      start_Q=0, max_Q=0,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,0)[4] intercept   : AIC=16612.809, Time=1.24 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=16622.715, Time=0.12 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=12430.363, Time=1.66 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=14041.985, Time=1.16 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=16622.672, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=13191.621, Time=0.31 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=12394.549, Time=2.33 sec
#  ARIMA(1,1,0)(3,0,0)[4] intercept   : AIC=12375.603, Time=3.48 sec
#  ARIMA(0,1,0)(3,0,0)[4] intercept   : AIC=16571.674, Time=2.79 sec
#  ARIMA(2,1,0)(3,0,0)[4] intercept   : AIC=10073.787, Time=4.18 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=10076.254, Time=4.46 sec
#  ARIMA(3,1,0)(3,0,0)[4] intercept   : AIC=9368.183, Time=3.20 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=9389.587, Time=2.52 sec
#  ARIMA(3,1,1)(3,0,0)[4] intercept   : AIC=9360.869, Time=6.09 sec
#  ARIMA(3,1,1)(2,0,0)[4] intercept   : AIC=9380.899, Time=4.32 sec
#  ARIMA(2,1,1)(3,0,0)[4] intercept   : AIC=9480.518, Time=4.26 sec
#  ARIMA(3,1,2)(3,0,0)[4] intercept   : AIC=9331.482, Time=8.24 sec
#  ARIMA(3,1,2)(2,0,0)[4] intercept   : AIC=9358.665, Time=6.05 sec
#  ARIMA(2,1,2)(3,0,0)[4] intercept   : AIC=9444.739, Time=4.78 sec
#  ARIMA(3,1,2)(3,0,0)[4]             : AIC=9329.673, Time=3.26 sec
#  ARIMA(3,1,2)(2,0,0)[4]             : AIC=9356.810, Time=2.67 sec
#  ARIMA(2,1,2)(3,0,0)[4]             : AIC=9443.173, Time=1.87 sec
#  ARIMA(3,1,1)(3,0,0)[4]             : AIC=9359.067, Time=2.26 sec
#  ARIMA(2,1,1)(3,0,0)[4]             : AIC=9479.035, Time=1.43 sec
#
# Best model:  ARIMA(3,1,2)(3,0,0)[4]
# Total fit time: 72.837 seconds

# %%
# auto arima vmd, lag 5
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=5,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=1, max_P=2,
                      start_Q=0, max_Q=0,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,0)[5] intercept   : AIC=16613.109, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=16622.715, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=11938.370, Time=1.18 sec
#  ARIMA(0,1,1)(0,0,0)[5] intercept   : AIC=14041.985, Time=0.63 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=16622.672, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[5] intercept   : AIC=13191.621, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,0)[5] intercept   : AIC=11932.594, Time=2.36 sec
#  ARIMA(0,1,0)(2,0,0)[5] intercept   : AIC=16559.637, Time=1.81 sec
#  ARIMA(2,1,0)(2,0,0)[5] intercept   : AIC=9911.393, Time=2.18 sec
#  ARIMA(2,1,0)(1,0,0)[5] intercept   : AIC=10070.365, Time=1.33 sec
#  ARIMA(3,1,0)(2,0,0)[5] intercept   : AIC=9415.736, Time=2.40 sec
#  ARIMA(3,1,0)(1,0,0)[5] intercept   : AIC=9422.520, Time=1.27 sec
#  ARIMA(3,1,1)(2,0,0)[5] intercept   : AIC=9400.726, Time=4.17 sec
#  ARIMA(3,1,1)(1,0,0)[5] intercept   : AIC=9421.596, Time=3.17 sec
#  ARIMA(2,1,1)(2,0,0)[5] intercept   : AIC=9426.955, Time=3.61 sec
#  ARIMA(3,1,2)(2,0,0)[5] intercept   : AIC=9372.212, Time=5.76 sec
#  ARIMA(3,1,2)(1,0,0)[5] intercept   : AIC=9378.195, Time=3.93 sec
#  ARIMA(2,1,2)(2,0,0)[5] intercept   : AIC=9417.676, Time=3.82 sec
#  ARIMA(3,1,2)(2,0,0)[5]             : AIC=9370.370, Time=2.42 sec
#  ARIMA(3,1,2)(1,0,0)[5]             : AIC=9376.358, Time=1.51 sec
#  ARIMA(2,1,2)(2,0,0)[5]             : AIC=9415.925, Time=1.20 sec
#  ARIMA(3,1,1)(2,0,0)[5]             : AIC=9398.946, Time=1.60 sec
#  ARIMA(2,1,1)(2,0,0)[5]             : AIC=9425.218, Time=0.92 sec
#
# Best model:  ARIMA(3,1,2)(2,0,0)[5]
# Total fit time: 46.166 seconds

# %%
# auto arima vmd, lag 6
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=6,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=1, max_P=1,
                      start_Q=0, max_Q=0,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=6)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,0,0)[6] intercept   : AIC=16607.964, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=16622.715, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=12580.407, Time=1.17 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=14041.985, Time=0.63 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=16622.672, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=13191.621, Time=0.16 sec
#  ARIMA(2,1,0)(1,0,0)[6] intercept   : AIC=10334.264, Time=1.10 sec
#  ARIMA(2,1,0)(0,0,0)[6] intercept   : AIC=10363.583, Time=0.41 sec
#  ARIMA(3,1,0)(1,0,0)[6] intercept   : AIC=9404.907, Time=1.45 sec
#  ARIMA(3,1,0)(0,0,0)[6] intercept   : AIC=9430.118, Time=0.49 sec
#  ARIMA(3,1,1)(1,0,0)[6] intercept   : AIC=9406.393, Time=2.52 sec
#  ARIMA(2,1,1)(1,0,0)[6] intercept   : AIC=9603.258, Time=1.48 sec
#  ARIMA(3,1,0)(1,0,0)[6]             : AIC=9403.116, Time=0.56 sec
#  ARIMA(3,1,0)(0,0,0)[6]             : AIC=9428.327, Time=0.22 sec
#  ARIMA(2,1,0)(1,0,0)[6]             : AIC=10333.289, Time=0.41 sec
#  ARIMA(3,1,1)(1,0,0)[6]             : AIC=9404.588, Time=0.99 sec
#  ARIMA(2,1,1)(1,0,0)[6]             : AIC=9601.932, Time=0.59 sec
#
# Best model:  ARIMA(3,1,0)(1,0,0)[6]
# Total fit time: 12.990 seconds

# %%
# auto arima vmd, lag 8
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=8,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=0,
                      start_Q=1, max_Q=3,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[8] intercept   : AIC=16593.501, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,0)[8] intercept   : AIC=16622.715, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[8] intercept   : AIC=13191.621, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[8] intercept   : AIC=13996.096, Time=1.93 sec
#  ARIMA(0,1,0)(0,0,0)[8]             : AIC=16622.672, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,1)[8] intercept   : AIC=13082.228, Time=1.23 sec
#  ARIMA(1,1,0)(0,0,2)[8] intercept   : AIC=13074.025, Time=2.95 sec
#  ARIMA(1,1,0)(0,0,3)[8] intercept   : AIC=12996.913, Time=6.38 sec
#  ARIMA(0,1,0)(0,0,3)[8] intercept   : AIC=16532.717, Time=7.05 sec
#  ARIMA(2,1,0)(0,0,3)[8] intercept   : AIC=10072.967, Time=7.62 sec
#  ARIMA(2,1,0)(0,0,2)[8] intercept   : AIC=10076.791, Time=2.89 sec
#  ARIMA(3,1,0)(0,0,3)[8] intercept   : AIC=9424.407, Time=6.65 sec
#  ARIMA(3,1,0)(0,0,2)[8] intercept   : AIC=9422.595, Time=3.23 sec
#  ARIMA(3,1,0)(0,0,1)[8] intercept   : AIC=9421.170, Time=1.50 sec
#  ARIMA(3,1,0)(0,0,0)[8] intercept   : AIC=9430.118, Time=0.49 sec
#  ARIMA(2,1,0)(0,0,1)[8] intercept   : AIC=10086.103, Time=1.22 sec
#  ARIMA(3,1,1)(0,0,1)[8] intercept   : AIC=9417.261, Time=3.00 sec
#  ARIMA(3,1,1)(0,0,0)[8] intercept   : AIC=9431.928, Time=1.20 sec
#  ARIMA(3,1,1)(0,0,2)[8] intercept   : AIC=9418.831, Time=6.30 sec
#  ARIMA(2,1,1)(0,0,1)[8] intercept   : AIC=9500.472, Time=2.15 sec
#  ARIMA(3,1,2)(0,0,1)[8] intercept   : AIC=9377.534, Time=5.69 sec
#  ARIMA(3,1,2)(0,0,0)[8] intercept   : AIC=9384.296, Time=1.92 sec
#  ARIMA(3,1,2)(0,0,2)[8] intercept   : AIC=9378.718, Time=9.55 sec
#  ARIMA(2,1,2)(0,0,1)[8] intercept   : AIC=9458.704, Time=2.78 sec
#  ARIMA(3,1,2)(0,0,1)[8]             : AIC=9375.693, Time=2.49 sec
#  ARIMA(3,1,2)(0,0,0)[8]             : AIC=9382.456, Time=0.89 sec
#  ARIMA(3,1,2)(0,0,2)[8]             : AIC=9376.867, Time=3.71 sec
#  ARIMA(2,1,2)(0,0,1)[8]             : AIC=9457.043, Time=0.96 sec
#  ARIMA(3,1,1)(0,0,1)[8]             : AIC=9415.495, Time=1.09 sec
#  ARIMA(2,1,1)(0,0,1)[8]             : AIC=9498.857, Time=0.70 sec
#
# Best model:  ARIMA(3,1,2)(0,0,1)[8]
# Total fit time: 86.792 seconds

# %%
# auto arima vmd, lag 9
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=9,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=0,
                      start_Q=1, max_Q=2,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[9] intercept   : AIC=16563.734, Time=0.95 sec
#  ARIMA(0,1,0)(0,0,0)[9] intercept   : AIC=16622.715, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[9] intercept   : AIC=13191.621, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[9] intercept   : AIC=13996.034, Time=1.78 sec
#  ARIMA(0,1,0)(0,0,0)[9]             : AIC=16622.672, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,1)[9] intercept   : AIC=12900.542, Time=1.49 sec
#  ARIMA(1,1,0)(0,0,2)[9] intercept   : AIC=12703.923, Time=3.13 sec
#  ARIMA(0,1,0)(0,0,2)[9] intercept   : AIC=16538.592, Time=2.16 sec
#  ARIMA(2,1,0)(0,0,2)[9] intercept   : AIC=9943.712, Time=3.38 sec
#  ARIMA(2,1,0)(0,0,1)[9] intercept   : AIC=10037.050, Time=1.74 sec
#  ARIMA(3,1,0)(0,0,2)[9] intercept   : AIC=9428.736, Time=3.87 sec
#  ARIMA(3,1,0)(0,0,1)[9] intercept   : AIC=9430.547, Time=1.99 sec
#  ARIMA(3,1,1)(0,0,2)[9] intercept   : AIC=9425.869, Time=6.70 sec
#  ARIMA(3,1,1)(0,0,1)[9] intercept   : AIC=9431.013, Time=2.97 sec
#  ARIMA(2,1,1)(0,0,2)[9] intercept   : AIC=9475.676, Time=5.33 sec
#  ARIMA(3,1,2)(0,0,2)[9] intercept   : AIC=9381.885, Time=10.43 sec
#  ARIMA(3,1,2)(0,0,1)[9] intercept   : AIC=9385.735, Time=5.22 sec
#  ARIMA(2,1,2)(0,0,2)[9] intercept   : AIC=9451.885, Time=5.62 sec
#  ARIMA(3,1,2)(0,0,2)[9]             : AIC=9380.018, Time=5.74 sec
#  ARIMA(3,1,2)(0,0,1)[9]             : AIC=9383.893, Time=2.57 sec
#  ARIMA(2,1,2)(0,0,2)[9]             : AIC=9450.100, Time=1.87 sec
#  ARIMA(3,1,1)(0,0,2)[9]             : AIC=9424.067, Time=2.48 sec
#  ARIMA(2,1,1)(0,0,2)[9]             : AIC=9473.891, Time=1.67 sec
#
# Best model:  ARIMA(3,1,2)(0,0,2)[9]
# Total fit time: 71.427 seconds

# %%
# auto arima vmd, lag 10
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=10,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=0,
                      start_Q=1, max_Q=1,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=6)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,1)[10] intercept   : AIC=16569.674, Time=1.07 sec
#  ARIMA(0,1,0)(0,0,0)[10] intercept   : AIC=16622.715, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[10] intercept   : AIC=13191.621, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,1)[10] intercept   : AIC=13965.528, Time=2.27 sec
#  ARIMA(0,1,0)(0,0,0)[10]             : AIC=16622.672, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,1)[10] intercept   : AIC=12840.088, Time=1.69 sec
#  ARIMA(2,1,0)(0,0,1)[10] intercept   : AIC=10090.984, Time=1.64 sec
#  ARIMA(2,1,0)(0,0,0)[10] intercept   : AIC=10363.583, Time=0.43 sec
#  ARIMA(3,1,0)(0,0,1)[10] intercept   : AIC=9426.522, Time=1.68 sec
#  ARIMA(3,1,0)(0,0,0)[10] intercept   : AIC=9430.118, Time=0.49 sec
#  ARIMA(3,1,1)(0,0,1)[10] intercept   : AIC=9425.418, Time=3.26 sec
#  ARIMA(3,1,1)(0,0,0)[10] intercept   : AIC=9431.928, Time=1.25 sec
#  ARIMA(2,1,1)(0,0,1)[10] intercept   : AIC=9518.606, Time=2.05 sec
#  ARIMA(3,1,2)(0,0,1)[10] intercept   : AIC=9382.780, Time=6.52 sec
#  ARIMA(3,1,2)(0,0,0)[10] intercept   : AIC=9384.296, Time=1.95 sec
#  ARIMA(2,1,2)(0,0,1)[10] intercept   : AIC=9474.797, Time=3.44 sec
#  ARIMA(3,1,2)(0,0,1)[10]             : AIC=9380.934, Time=2.38 sec
#  ARIMA(3,1,2)(0,0,0)[10]             : AIC=9382.456, Time=0.91 sec
#  ARIMA(2,1,2)(0,0,1)[10]             : AIC=9473.111, Time=1.04 sec
#  ARIMA(3,1,1)(0,0,1)[10]             : AIC=9423.635, Time=1.34 sec
#  ARIMA(2,1,1)(0,0,1)[10]             : AIC=9516.943, Time=0.77 sec
#
# Best model:  ARIMA(3,1,2)(0,0,1)[10]
# Total fit time: 34.531 seconds

# %%
# best vmd models with seasonal components to this point:

# seasonal moving average
(3,1,2)(0,0,1)[10]  AIC:6067
(3,1,2)(0,0,3)[8]   AIC:6072

# seasonal autoregressive
(3,1,2)(2,0,0)[5]   AIC:6060
# Out:
#   File "<ipython-input-36-039f58841411>", line 4
#     (3,1,2)(0,0,1)[10]  AIC:6067
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 6 Expand search around most promising seasonal orders

# %%
# auto arima vmd, lag 10
vmd_arima = pm.auto_arima(vmd_in, start_p=2, start_q=1,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=10,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=2,
                      start_Q=0, max_Q=2,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=8)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(0,0,0)[10] intercept   : AIC=9608.251, Time=0.80 sec
#  ARIMA(0,1,0)(0,0,0)[10] intercept   : AIC=16622.715, Time=0.09 sec
#  ARIMA(1,1,0)(1,0,0)[10] intercept   : AIC=12780.019, Time=1.36 sec
#  ARIMA(0,1,1)(0,0,1)[10] intercept   : AIC=13965.528, Time=2.23 sec
#  ARIMA(0,1,0)(0,0,0)[10]             : AIC=16622.672, Time=0.06 sec
#  ARIMA(2,1,1)(1,0,0)[10] intercept   : AIC=9509.323, Time=2.15 sec
#  ARIMA(2,1,1)(2,0,0)[10] intercept   : AIC=9511.319, Time=5.97 sec
#  ARIMA(2,1,1)(1,0,1)[10] intercept   : AIC=9511.321, Time=3.42 sec
#  ARIMA(2,1,1)(0,0,1)[10] intercept   : AIC=9518.606, Time=2.04 sec
#  ARIMA(2,1,1)(2,0,1)[10] intercept   : AIC=9511.318, Time=13.18 sec
#  ARIMA(1,1,1)(1,0,0)[10] intercept   : AIC=10805.317, Time=1.67 sec
#  ARIMA(2,1,0)(1,0,0)[10] intercept   : AIC=10072.225, Time=1.63 sec
#  ARIMA(3,1,1)(1,0,0)[10] intercept   : AIC=9424.162, Time=3.06 sec
#  ARIMA(3,1,1)(0,0,0)[10] intercept   : AIC=9431.928, Time=1.27 sec
#  ARIMA(3,1,1)(2,0,0)[10] intercept   : AIC=9423.454, Time=8.34 sec
#  ARIMA(3,1,1)(2,0,1)[10] intercept   : AIC=9422.705, Time=17.82 sec
#  ARIMA(3,1,1)(1,0,1)[10] intercept   : AIC=9424.945, Time=5.02 sec
#  ARIMA(3,1,1)(2,0,2)[10] intercept   : AIC=9415.133, Time=25.19 sec
#  ARIMA(3,1,1)(1,0,2)[10] intercept   : AIC=9422.143, Time=19.11 sec
#  ARIMA(2,1,1)(2,0,2)[10] intercept   : AIC=9499.754, Time=15.63 sec
#  ARIMA(3,1,0)(2,0,2)[10] intercept   : AIC=inf, Time=17.79 sec
#  ARIMA(3,1,2)(2,0,2)[10] intercept   : AIC=inf, Time=27.03 sec
#  ARIMA(2,1,0)(2,0,2)[10] intercept   : AIC=10040.201, Time=11.06 sec
#  ARIMA(2,1,2)(2,0,2)[10] intercept   : AIC=9459.904, Time=16.89 sec
#  ARIMA(3,1,1)(2,0,2)[10]             : AIC=9413.339, Time=9.07 sec
#  ARIMA(3,1,1)(1,0,2)[10]             : AIC=9420.334, Time=6.46 sec
#  ARIMA(3,1,1)(2,0,1)[10]             : AIC=9420.894, Time=6.31 sec
#  ARIMA(3,1,1)(1,0,1)[10]             : AIC=9423.141, Time=2.14 sec
#  ARIMA(2,1,1)(2,0,2)[10]             : AIC=9498.055, Time=4.57 sec
#  ARIMA(3,1,0)(2,0,2)[10]             : AIC=inf, Time=11.65 sec
#  ARIMA(3,1,2)(2,0,2)[10]             : AIC=inf, Time=17.34 sec
#  ARIMA(2,1,0)(2,0,2)[10]             : AIC=10038.468, Time=4.35 sec
#  ARIMA(2,1,2)(2,0,2)[10]             : AIC=9458.193, Time=6.53 sec
#
# Best model:  ARIMA(3,1,1)(2,0,2)[10]
# Total fit time: 271.306 seconds

# %%
# auto arima vmd, lag 8
vmd_arima = pm.auto_arima(vmd_in, start_p=2, start_q=1,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=8,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=2,
                      start_Q=0, max_Q=3,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=8)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(0,0,0)[8] intercept   : AIC=9608.251, Time=0.77 sec
#  ARIMA(0,1,0)(0,0,0)[8] intercept   : AIC=16622.715, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[8] intercept   : AIC=13086.607, Time=1.30 sec
#  ARIMA(0,1,1)(0,0,1)[8] intercept   : AIC=13996.096, Time=1.93 sec
#  ARIMA(0,1,0)(0,0,0)[8]             : AIC=16622.672, Time=0.07 sec
#  ARIMA(2,1,1)(1,0,0)[8] intercept   : AIC=9502.530, Time=1.87 sec
#  ARIMA(2,1,1)(2,0,0)[8] intercept   : AIC=9499.525, Time=4.70 sec
#  ARIMA(2,1,1)(2,0,1)[8] intercept   : AIC=9491.482, Time=7.36 sec
#  ARIMA(2,1,1)(1,0,1)[8] intercept   : AIC=9501.144, Time=3.25 sec
#  ARIMA(2,1,1)(2,0,2)[8] intercept   : AIC=9488.535, Time=10.88 sec
#  ARIMA(2,1,1)(1,0,2)[8] intercept   : AIC=9501.910, Time=8.59 sec
#  ARIMA(2,1,1)(2,0,3)[8] intercept   : AIC=9481.598, Time=32.02 sec
#  ARIMA(2,1,1)(1,0,3)[8] intercept   : AIC=9493.957, Time=17.12 sec
#  ARIMA(1,1,1)(2,0,3)[8] intercept   : AIC=10955.482, Time=26.01 sec
#  ARIMA(2,1,0)(2,0,3)[8] intercept   : AIC=10047.640, Time=17.65 sec
#  ARIMA(3,1,1)(2,0,3)[8] intercept   : AIC=9408.200, Time=39.78 sec
#  ARIMA(3,1,1)(1,0,3)[8] intercept   : AIC=9420.968, Time=20.47 sec
#  ARIMA(3,1,1)(2,0,2)[8] intercept   : AIC=9408.057, Time=15.80 sec
#  ARIMA(3,1,1)(1,0,2)[8] intercept   : AIC=9420.425, Time=14.11 sec
#  ARIMA(3,1,1)(2,0,1)[8] intercept   : AIC=9419.924, Time=13.18 sec
#  ARIMA(3,1,1)(1,0,1)[8] intercept   : AIC=9418.962, Time=5.29 sec
#  ARIMA(3,1,0)(2,0,2)[8] intercept   : AIC=9412.357, Time=14.95 sec
#  ARIMA(3,1,2)(2,0,2)[8] intercept   : AIC=9368.022, Time=25.03 sec
#  ARIMA(3,1,2)(1,0,2)[8] intercept   : AIC=9380.697, Time=14.39 sec
#  ARIMA(3,1,2)(2,0,1)[8] intercept   : AIC=9381.135, Time=12.33 sec
#  ARIMA(3,1,2)(2,0,3)[8] intercept   : AIC=9369.619, Time=48.48 sec
#  ARIMA(3,1,2)(1,0,1)[8] intercept   : AIC=9378.926, Time=7.54 sec
#  ARIMA(3,1,2)(1,0,3)[8] intercept   : AIC=9382.283, Time=30.10 sec
#  ARIMA(2,1,2)(2,0,2)[8] intercept   : AIC=9448.036, Time=17.90 sec
#  ARIMA(3,1,2)(2,0,2)[8]             : AIC=9366.174, Time=11.34 sec
#  ARIMA(3,1,2)(1,0,2)[8]             : AIC=9378.848, Time=5.70 sec
#  ARIMA(3,1,2)(2,0,1)[8]             : AIC=9379.289, Time=3.64 sec
#  ARIMA(3,1,2)(2,0,3)[8]             : AIC=9367.834, Time=16.94 sec
#  ARIMA(3,1,2)(1,0,1)[8]             : AIC=9377.076, Time=3.35 sec
#  ARIMA(3,1,2)(1,0,3)[8]             : AIC=9380.445, Time=11.48 sec
#  ARIMA(2,1,2)(2,0,2)[8]             : AIC=9446.415, Time=6.08 sec
#  ARIMA(3,1,1)(2,0,2)[8]             : AIC=9406.310, Time=9.82 sec
#  ARIMA(2,1,1)(2,0,2)[8]             : AIC=9486.968, Time=4.48 sec
#
# Best model:  ARIMA(3,1,2)(2,0,2)[8]
# Total fit time: 485.898 seconds

# %%
# auto arima vmd, lag 5
vmd_arima = pm.auto_arima(vmd_in, start_p=2, start_q=1,
                      test='adf',
                      max_p=3, max_q=2, # maximum p and q
                      m=5,              # frequency of series
                      d=1,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=3,
                      start_Q=0, max_Q=2,
                      D=0,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=8)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(0,0,0)[5] intercept   : AIC=9608.251, Time=0.77 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=16622.715, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=11938.370, Time=1.19 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=14015.918, Time=1.53 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=16622.672, Time=0.06 sec
#  ARIMA(2,1,1)(1,0,0)[5] intercept   : AIC=9513.073, Time=1.54 sec
#  ARIMA(2,1,1)(2,0,0)[5] intercept   : AIC=9426.955, Time=2.79 sec
#  ARIMA(2,1,1)(3,0,0)[5] intercept   : AIC=9424.372, Time=4.13 sec
#  ARIMA(2,1,1)(3,0,1)[5] intercept   : AIC=9423.664, Time=10.62 sec
#  ARIMA(2,1,1)(2,0,1)[5] intercept   : AIC=9425.709, Time=3.53 sec
#  ARIMA(2,1,1)(3,0,2)[5] intercept   : AIC=9417.244, Time=17.33 sec
#  ARIMA(2,1,1)(2,0,2)[5] intercept   : AIC=9415.519, Time=6.76 sec
#  ARIMA(2,1,1)(1,0,2)[5] intercept   : AIC=9421.417, Time=4.08 sec
#  ARIMA(2,1,1)(1,0,1)[5] intercept   : AIC=9440.850, Time=2.40 sec
#  ARIMA(1,1,1)(2,0,2)[5] intercept   : AIC=10092.294, Time=6.69 sec
#  ARIMA(2,1,0)(2,0,2)[5] intercept   : AIC=9865.816, Time=5.09 sec
#  ARIMA(3,1,1)(2,0,2)[5] intercept   : AIC=9386.909, Time=12.60 sec
#  ARIMA(3,1,1)(1,0,2)[5] intercept   : AIC=9392.418, Time=6.25 sec
#  ARIMA(3,1,1)(2,0,1)[5] intercept   : AIC=9393.444, Time=7.28 sec
#  ARIMA(3,1,1)(3,0,2)[5] intercept   : AIC=9388.170, Time=22.99 sec
#  ARIMA(3,1,1)(1,0,1)[5] intercept   : AIC=9396.025, Time=9.29 sec
#  ARIMA(3,1,1)(3,0,1)[5] intercept   : AIC=9393.490, Time=13.04 sec
#  ARIMA(3,1,0)(2,0,2)[5] intercept   : AIC=9405.852, Time=12.06 sec
#  ARIMA(3,1,2)(2,0,2)[5] intercept   : AIC=9360.078, Time=16.37 sec
#  ARIMA(3,1,2)(1,0,2)[5] intercept   : AIC=9365.794, Time=8.70 sec
#  ARIMA(3,1,2)(2,0,1)[5] intercept   : AIC=9366.162, Time=8.84 sec
#  ARIMA(3,1,2)(3,0,2)[5] intercept   : AIC=9357.511, Time=26.34 sec
#  ARIMA(3,1,2)(3,0,1)[5] intercept   : AIC=9365.480, Time=15.94 sec
#  ARIMA(2,1,2)(3,0,2)[5] intercept   : AIC=9405.434, Time=22.82 sec
#  ARIMA(3,1,2)(3,0,2)[5]             : AIC=9358.114, Time=10.17 sec
#
# Best model:  ARIMA(3,1,2)(3,0,2)[5] intercept
# Total fit time: 261.344 seconds

# %% [markdown]
# # 7 Check stationarity assumption of seasonal differencing

# %%
# Due to the pattern in non-differenced emd and vmd PACFs, checks are necessary on stationarity, ACF and PACF after seasonal differencing
# Try emd seasonal differencing @ lag 4, and vmd seasonal differencing @ lag 5

# %%
# EMD differenced at lag 4 passes stationarity test
result = adfuller(emd_in['value'].diff(4).dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -9.529761
# p-value: 0.000000

# %%
# VMD differenced at lag 5 passes stationarity test
result = adfuller(vmd_in['value'].diff(5).dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -10.023447
# p-value: 0.000000

# %% [markdown]
# # 8 Visualise ACF and PACF plots for seasonally-differenced series

# %%
# ACF emd, 1 diff at lag 4

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(emd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = emd_in['value'].values
lags_n = 110
plot_acf(series_data, ax=axes[0, 1], lags=lags_n)

# 1st Differencing
axes[1, 0].plot(emd_in['value'].diff(4).values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = emd_in['value'].diff(4).dropna().values
first_diff_lags_n = 110
plot_acf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n)

plt.show()

# %%
# PACF emd, 1 diff at lag 4

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(emd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = emd_in['value'].values
lags_n = 110
plot_pacf(series_data, ax=axes[0, 1], lags=lags_n, method='ywm')

# 1st Differencing
axes[1, 0].plot(emd_in['value'].diff(4).values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = emd_in['value'].diff(4).dropna().values
first_diff_lags_n = 110
plot_pacf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n, method='ywm')

plt.show()

# %%
# 3, 3 shows promise in this case

# %%
# ACF vmd, 1 diff at lag 5

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(vmd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = vmd_in['value'].values
lags_n = 110
plot_acf(series_data, ax=axes[0, 1], lags=lags_n)

# 1st Differencing
axes[1, 0].plot(vmd_in['value'].diff(5).values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = vmd_in['value'].diff(5).dropna().values
first_diff_lags_n = 30
plot_acf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n)

plt.show()

# %%
# PACF vmd, 1 diff at lag 5

plt.rcParams.update({'figure.figsize':(16,8)})

# Original Series
fig, axes = plt.subplots(2, 2)#, sharex=True)
axes[0, 0].plot(vmd_in['value'].dropna().values)
axes[0, 0].set_title('Original Series')
series_data = vmd_in['value'].values
lags_n = 110
plot_pacf(series_data, ax=axes[0, 1], lags=lags_n, method='ywm')

# 1st Differencing
axes[1, 0].plot(vmd_in['value'].diff(5).values)
axes[1, 0].set_title('1st Order Differencing')
first_diff_series = vmd_in['value'].diff(5).dropna().values
first_diff_lags_n = 25
plot_pacf(first_diff_series, ax=axes[1, 1], lags=first_diff_lags_n, method='ywm')

plt.show()

# %%
# Anything up to 4, 4 may work well

# %% [markdown]
# # 9 Investigate seasonally-differenced model order

# %%
# auto arima emd, seasonal difference lag 4
emd_arima = pm.auto_arima(emd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=3, max_q=3, # maximum p and q
                      m=4,              # frequency of series
                      d=0,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=1,
                      start_Q=0, max_Q=3,
                      D=1,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=22085.335, Time=0.06 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=17640.713, Time=1.93 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=2.15 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=22085.896, Time=0.07 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=18268.193, Time=0.19 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=5.81 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=inf, Time=2.68 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=21986.584, Time=1.18 sec
#  ARIMA(2,0,0)(1,1,0)[4] intercept   : AIC=14183.659, Time=2.13 sec
#  ARIMA(2,0,0)(0,1,0)[4] intercept   : AIC=15281.953, Time=0.65 sec
#  ARIMA(2,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=5.05 sec
#  ARIMA(2,0,0)(0,1,1)[4] intercept   : AIC=inf, Time=3.71 sec
#  ARIMA(3,0,0)(1,1,0)[4] intercept   : AIC=12362.809, Time=2.47 sec
#  ARIMA(3,0,0)(0,1,0)[4] intercept   : AIC=12646.106, Time=0.83 sec
#  ARIMA(3,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=9.29 sec
#  ARIMA(3,0,0)(0,1,1)[4] intercept   : AIC=inf, Time=6.27 sec
#  ARIMA(3,0,1)(1,1,0)[4] intercept   : AIC=inf, Time=5.32 sec
#  ARIMA(2,0,1)(1,1,0)[4] intercept   : AIC=inf, Time=4.14 sec
#  ARIMA(3,0,0)(1,1,0)[4]             : AIC=12360.919, Time=0.86 sec
#  ARIMA(3,0,0)(0,1,0)[4]             : AIC=12644.190, Time=0.33 sec
#  ARIMA(3,0,0)(1,1,1)[4]             : AIC=inf, Time=4.60 sec
#  ARIMA(3,0,0)(0,1,1)[4]             : AIC=inf, Time=4.65 sec
#  ARIMA(2,0,0)(1,1,0)[4]             : AIC=14182.796, Time=0.72 sec
#  ARIMA(3,0,1)(1,1,0)[4]             : AIC=inf, Time=2.94 sec
#  ARIMA(2,0,1)(1,1,0)[4]             : AIC=inf, Time=2.48 sec
#
# Best model:  ARIMA(3,0,0)(1,1,0)[4]
# Total fit time: 70.570 seconds

# %%
# auto arima vmd, seasonal difference lag 5
vmd_arima = pm.auto_arima(vmd_in, start_p=0, start_q=0,
                      test='adf',
                      max_p=4, max_q=4, # maximum p and q
                      m=5,              # frequency of series
                      d=0,              # stationarity is achieved with one differencing
                      seasonal=True,
                      start_P=0, max_P=2,
                      start_Q=0, max_Q=2,
                      D=1,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True,
                      max_order=8)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[5] intercept   : AIC=22489.700, Time=0.08 sec
#  ARIMA(1,0,0)(1,1,0)[5] intercept   : AIC=17179.569, Time=1.89 sec
#  ARIMA(0,0,1)(0,1,1)[5] intercept   : AIC=inf, Time=3.23 sec
#  ARIMA(0,0,0)(0,1,0)[5]             : AIC=22490.758, Time=0.08 sec
#  ARIMA(1,0,0)(0,1,0)[5] intercept   : AIC=18101.924, Time=0.22 sec
#  ARIMA(1,0,0)(2,1,0)[5] intercept   : AIC=17133.934, Time=4.12 sec
#  ARIMA(1,0,0)(2,1,1)[5] intercept   : AIC=inf, Time=7.40 sec
#  ARIMA(1,0,0)(1,1,1)[5] intercept   : AIC=inf, Time=5.88 sec
#  ARIMA(0,0,0)(2,1,0)[5] intercept   : AIC=22419.822, Time=3.21 sec
#  ARIMA(2,0,0)(2,1,0)[5] intercept   : AIC=12144.965, Time=5.24 sec
#  ARIMA(2,0,0)(1,1,0)[5] intercept   : AIC=12571.354, Time=2.26 sec
#  ARIMA(2,0,0)(2,1,1)[5] intercept   : AIC=11856.977, Time=13.47 sec
#  ARIMA(2,0,0)(1,1,1)[5] intercept   : AIC=11868.843, Time=6.11 sec
#  ARIMA(2,0,0)(2,1,2)[5] intercept   : AIC=11851.972, Time=13.99 sec
#  ARIMA(2,0,0)(1,1,2)[5] intercept   : AIC=11853.357, Time=10.55 sec
#  ARIMA(1,0,0)(2,1,2)[5] intercept   : AIC=inf, Time=12.96 sec
#  ARIMA(3,0,0)(2,1,2)[5] intercept   : AIC=inf, Time=16.58 sec
#  ARIMA(2,0,1)(2,1,2)[5] intercept   : AIC=inf, Time=16.79 sec
#  ARIMA(1,0,1)(2,1,2)[5] intercept   : AIC=inf, Time=13.56 sec
#  ARIMA(3,0,1)(2,1,2)[5] intercept   : AIC=inf, Time=18.15 sec
#  ARIMA(2,0,0)(2,1,2)[5]             : AIC=11849.156, Time=8.28 sec
#  ARIMA(2,0,0)(1,1,2)[5]             : AIC=11857.904, Time=4.75 sec
#  ARIMA(2,0,0)(2,1,1)[5]             : AIC=11861.813, Time=3.67 sec
#  ARIMA(2,0,0)(1,1,1)[5]             : AIC=11874.094, Time=2.22 sec
#  ARIMA(1,0,0)(2,1,2)[5]             : AIC=inf, Time=10.82 sec
#  ARIMA(3,0,0)(2,1,2)[5]             : AIC=inf, Time=9.56 sec
#  ARIMA(2,0,1)(2,1,2)[5]             : AIC=inf, Time=10.30 sec
#  ARIMA(1,0,1)(2,1,2)[5]             : AIC=inf, Time=12.45 sec
#  ARIMA(3,0,1)(2,1,2)[5]             : AIC=inf, Time=16.43 sec
#
# Best model:  ARIMA(2,0,0)(2,1,2)[5]
# Total fit time: 234.317 seconds

# %%
# Best models found to this point:

#emd (3,0,0)(1,1,0)[4]
#vmd (2,0,0)(2,1,2)[5]

# %% [markdown]
# # 10 Generate validation set predictions, for use in forecast combination step

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
predictions_rolling = []

for i in range(len(emd_valid)):

  train_set = pd.concat([emd_train, emd_valid[:i]]) #concatenating here is quite inefficient, and avoidable

  emd_arima_model = ARIMA(train_set['value'].dropna().values, order=(3, 0, 0),seasonal_order=(1, 1, 0, 4), enforce_stationarity=False)  
  emd_arima_fit = emd_arima_model.fit()

  fc = emd_arima_fit.forecast()
  predictions_rolling.append(fc[0])

with open(f'/content/gdrive/MyDrive/outputs/test/emd_ARIMA_weekly_valid.json', 'w') as fp:
  json.dump(predictions_rolling, fp)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
predictions_rolling = []

for i in range(len(vmd_valid)):

  train_set = pd.concat([vmd_train, vmd_valid[:i]]) #concatenating here is quite inefficient, and avoidable

  vmd_arima_model = ARIMA(train_set['value'].dropna().values, order=(2, 0, 0), seasonal_order=(2, 1, 2, 5), enforce_stationarity=False)  
  vmd_arima_fit = vmd_arima_model.fit()

  fc = vmd_arima_fit.forecast()
  predictions_rolling.append(fc[0])

with open(f'/content/gdrive/MyDrive/outputs/test/vmd_ARIMA_weekly_valid.json', 'w') as fp:
  json.dump(predictions_rolling, fp)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %% [markdown]
# # 11 Generate test set predictions

# %%
predictions_rolling = []

for i in range(len(emd_test)):

  train_set = pd.concat([emd_in, emd_test[:i]]) #concatenating here is quite inefficient, and avoidable

  emd_arima_model = ARIMA(train_set['value'].dropna().values, order=(3, 0, 0),seasonal_order=(1, 1, 0, 4), enforce_stationarity=False)  
  emd_arima_fit = emd_arima_model.fit()

  fc = emd_arima_fit.forecast()
  predictions_rolling.append(fc[0])

with open(f'/content/gdrive/MyDrive/outputs/test/emd_ARIMA_weekly_test.json', 'w') as fp:
  json.dump(predictions_rolling, fp)

# %%
predictions_rolling = []

for i in range(len(vmd_test)):

  train_set = pd.concat([vmd_in, vmd_test[:i]]) #concatenating here is quite inefficient, and avoidable

  vmd_arima_model = ARIMA(train_set['value'].dropna().values,  order=(2, 0, 0), seasonal_order=(2, 1, 2, 5), enforce_stationarity=False)  
  vmd_arima_fit = vmd_arima_model.fit()

  fc = vmd_arima_fit.forecast()
  predictions_rolling.append(fc[0])

with open(f'/content/gdrive/MyDrive/outputs/test/vmd_ARIMA_weekly_test.json', 'w') as fp:
  json.dump(predictions_rolling, fp)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %% [markdown]
# # End
