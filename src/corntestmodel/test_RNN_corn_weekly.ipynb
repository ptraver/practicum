# %% [markdown]
# # This book is identical to RNN_corn_weekly.ipynb, except for the generation of test set predictions after validation set predictions

# %% [markdown]
# ### CONTENTS
# ### 1 Imports
# ### 2 Arrange datasets
# ### 3 Define models
# ### 4 Train models

# %% [markdown]
# # 1 Imports

# %%
# RNN imports

import tensorflow as tf

from keras.preprocessing.sequence import TimeseriesGenerator

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN

from keras.models import load_model

from tensorflow.keras.callbacks import ModelCheckpoint

# %%
#General imports

import numpy as np
import pandas as pd

import scipy.stats as stats

import matplotlib.pyplot as plt
import matplotlib.dates

from datetime import datetime

from google.colab import drive
import json

# %%
# Import weekly data

data_url = 'https://raw.githubusercontent.com/ptraver/data/main/corn_weekly.csv'
corn_df = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# fix bad name
corn_df.columns = ['value']

# take only 1974 - 2017
corn_df = corn_df['1974-01-01':'2017-12-31']

# corn_df needs to lose last value becuase during process of VMD, the last value is lost
corn_df = corn_df[:-1]

# view loaded data
corn_df.tail(2)
# Out:
#              value
# date
# 2017-12-10  339.30
# 2017-12-17  338.85

# %%
# Import emd data
data_url = 'https://raw.githubusercontent.com/ptraver/data/main/corn_emd_weekly.csv'
corn_emd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Import vmd data
data_url = 'https://raw.githubusercontent.com/ptraver/data/main/corn_vmd_weekly.csv'
corn_vmd = pd.read_csv(data_url, parse_dates=True, dayfirst=True, index_col='date')

# %%
# Check indices are aligned
print(corn_df.index.equals(corn_emd.index))
print(corn_df.index.equals(corn_vmd.index))
# Out:
# True
# True

# %% [markdown]
# # 2 Arrange datasets

# %%
# Split data so that valid and test do not feature in decisions
from sklearn.model_selection import train_test_split

true_train, out_of_sample = train_test_split(corn_df, test_size=0.2, shuffle=False)
true_valid, true_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

emd_train, out_of_sample = train_test_split(corn_emd, test_size=0.2, shuffle=False)
emd_valid, emd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

vmd_train, out_of_sample = train_test_split(corn_vmd, test_size=0.2, shuffle=False)
vmd_valid, vmd_test = train_test_split(out_of_sample, test_size=0.5, shuffle=False)

# %%
# Scale data between 0 and 1
from sklearn.preprocessing import MinMaxScaler

emd_scaler = MinMaxScaler()
emd_train = emd_scaler.fit_transform(emd_train)
emd_valid = emd_scaler.transform(emd_valid)
emd_test = emd_scaler.transform(emd_test)

vmd_scaler = MinMaxScaler()
vmd_train = vmd_scaler.fit_transform(vmd_train)
vmd_valid = vmd_scaler.transform(vmd_valid)
vmd_test = vmd_scaler.transform(vmd_test)

true_scaler = MinMaxScaler()
true_train = true_scaler.fit_transform(true_train)
true_valid = true_scaler.transform(true_valid)
true_test = true_scaler.transform(true_test)

# %%
# Set input shape variables
emd_n_inputs = 4
vmd_n_inputs = 5
non_decomp_n_inputs = 5

# %%
# get emd sets in order
emd_extra_valid = emd_train[-emd_n_inputs:]
emd_valid_set = np.concatenate((emd_extra_valid, emd_valid))

emd_extra_test = emd_valid[-emd_n_inputs:]
emd_test_set = np.concatenate((emd_extra_test, emd_test))

emd_train_shaped = TimeseriesGenerator(emd_train, emd_train, length=emd_n_inputs, batch_size=1)
emd_valid_shaped = TimeseriesGenerator(emd_valid_set, emd_valid_set, length=emd_n_inputs, batch_size=1)
emd_test_shaped = TimeseriesGenerator(emd_test_set, emd_test_set, length=emd_n_inputs, batch_size=1)

# %%
# get vmd sets in order
vmd_extra_valid = vmd_train[-vmd_n_inputs:]
vmd_valid_set = np.concatenate((vmd_extra_valid, vmd_valid))

vmd_extra_test = vmd_valid[-vmd_n_inputs:]
vmd_test_set = np.concatenate((vmd_extra_test, vmd_test))

vmd_train_shaped = TimeseriesGenerator(vmd_train, vmd_train, length=vmd_n_inputs, batch_size=1)
vmd_valid_shaped = TimeseriesGenerator(vmd_valid_set, vmd_valid_set, length=vmd_n_inputs, batch_size=1)
vmd_test_shaped = TimeseriesGenerator(vmd_test_set, vmd_test_set, length=vmd_n_inputs, batch_size=1)

# %%
# get non-decomposed sets in order
extra_valid = true_train[-non_decomp_n_inputs:]
valid_set = np.concatenate((extra_valid, true_valid))

extra_test = true_valid[-non_decomp_n_inputs:]
test_set = np.concatenate((extra_test, true_test))

train_shaped = TimeseriesGenerator(true_train, true_train, length=non_decomp_n_inputs, batch_size=1)
valid_shaped = TimeseriesGenerator(valid_set, valid_set, length=non_decomp_n_inputs, batch_size=1)
test_shaped = TimeseriesGenerator(test_set, test_set, length=non_decomp_n_inputs, batch_size=1)

# %% [markdown]
# # 3 Define models

# %%
# Set shape variables
emd_units = 7

vmd_L1_units = 7
vmd_L2_units = 4

non_decomp_units = 7

# Set number of features
n_features = 1

# %%
# Set other variables
activation = 'relu'
dropout = 0
optimizer = 'adam'
loss = 'mse'

# %%
# Define emd model definition function

def define_emd_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=emd_units, input_shape=(emd_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %%
# Define vmd model definition function

def define_vmd_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=vmd_L1_units, input_shape=(vmd_n_inputs, n_features), activation=activation, dropout=dropout, return_sequences=True))
  RNNregressor.add(SimpleRNN(units=vmd_L2_units, input_shape=(vmd_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %%
# Define non decomp model definition function

def define_non_decomp_model():
  RNNregressor = Sequential()
  RNNregressor.add(SimpleRNN(units=non_decomp_units, input_shape=(non_decomp_n_inputs, n_features), activation=activation, dropout=dropout))
  RNNregressor.add(Dense(units=1))
  RNNregressor.compile(optimizer=optimizer, loss=loss)
  return RNNregressor

# %% [markdown]
# # 4 Train models

# %%
# Set variables

decomp_EPOCHS = 50
non_decomp_EPOCHS = 8

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###on EMD corn weekly

# %%
# Set checkpoint callback
filepath = 'emd_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
EMDregressor = define_emd_model()

# Train model
with tf.device('/device:GPU:0'):
  EMDregressor.fit(emd_train_shaped,
                   epochs=decomp_EPOCHS,
                   validation_data=emd_valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 0.0079INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_01.model/assets
# 1831/1831 [==============================] - 15s 7ms/step - loss: 0.0079 - val_loss: 0.0042
# Epoch 2/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 3.0629e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_02.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 3.0529e-04 - val_loss: 0.0035
# Epoch 3/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 2.3276e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_03.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 2.3247e-04 - val_loss: 0.0012
# Epoch 4/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 2.0850e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_04.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 2.0854e-04 - val_loss: 7.9195e-04
# Epoch 5/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 1.9256e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_05.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 1.9239e-04 - val_loss: 0.0014
# Epoch 6/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 1.6222e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_06.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 1.6214e-04 - val_loss: 0.0012
# Epoch 7/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 1.3250e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_07.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 1.3221e-04 - val_loss: 0.0016
# Epoch 8/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 1.2095e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_08.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 1.2063e-04 - val_loss: 0.0011
# Epoch 9/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 1.1183e-04INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_09.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 1.1164e-04 - val_loss: 5.5728e-04
# Epoch 10/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 8.8667e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_10.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 8.8346e-05 - val_loss: 3.7444e-04
# Epoch 11/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 8.3481e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_11.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 8.3567e-05 - val_loss: 7.8179e-04
# Epoch 12/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 6.3652e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_12.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 6.4258e-05 - val_loss: 3.7986e-04
# Epoch 13/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 6.0550e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_13.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 6.0500e-05 - val_loss: 2.2907e-04
# Epoch 14/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 4.6628e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_14.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 4.6683e-05 - val_loss: 2.2083e-04
# Epoch 15/50
# 1831/1831 [==============================] - ETA: 0s - loss: 4.6240e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_15.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 4.6240e-05 - val_loss: 3.8954e-04
# Epoch 16/50
# 1822/1831 [============================>.] - ETA: 0s - loss: 4.3972e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_16.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 4.3821e-05 - val_loss: 1.6616e-04
# Epoch 17/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 3.3789e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_17.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 3.3708e-05 - val_loss: 0.0011
# Epoch 18/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 3.7224e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_18.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 3.7287e-05 - val_loss: 1.5955e-04
# Epoch 19/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 3.7078e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_19.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 3.7024e-05 - val_loss: 3.6161e-04
# Epoch 20/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 2.8629e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_20.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 2.8579e-05 - val_loss: 1.5422e-04
# Epoch 21/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 3.0090e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_21.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 3.0059e-05 - val_loss: 1.5551e-04
# Epoch 22/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 2.9822e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_22.model/assets
# 1831/1831 [==============================] - 12s 7ms/step - loss: 2.9740e-05 - val_loss: 1.3415e-04
# Epoch 23/50
# 1831/1831 [==============================] - ETA: 0s - loss: 3.0139e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_23.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 3.0139e-05 - val_loss: 2.3124e-04
# Epoch 24/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 2.7449e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_24.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.7447e-05 - val_loss: 2.4910e-04
# Epoch 25/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 2.7144e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_25.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.7649e-05 - val_loss: 8.1917e-04
# Epoch 26/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 2.7385e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_26.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 2.7376e-05 - val_loss: 0.0031
# Epoch 27/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 2.8076e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_27.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.8328e-05 - val_loss: 1.4909e-04
# Epoch 28/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 2.4323e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_28.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.4297e-05 - val_loss: 1.9429e-04
# Epoch 29/50
# 1830/1831 [============================>.] - ETA: 0s - loss: 2.6600e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_29.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 2.6586e-05 - val_loss: 1.1622e-04
# Epoch 30/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 2.5010e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_30.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.4977e-05 - val_loss: 1.3613e-04
# Epoch 31/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 2.5757e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_31.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.5718e-05 - val_loss: 3.3907e-04
# Epoch 32/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 2.3969e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_32.model/assets
# 1831/1831 [==============================] - 15s 8ms/step - loss: 2.3943e-05 - val_loss: 1.3963e-04
# Epoch 33/50
# 1823/1831 [============================>.] - ETA: 0s - loss: 2.4217e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_33.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.4269e-05 - val_loss: 1.1767e-04
# Epoch 34/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 2.3381e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_34.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 2.3365e-05 - val_loss: 1.2054e-04
# Epoch 35/50
# 1831/1831 [==============================] - ETA: 0s - loss: 2.0628e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_35.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 2.0628e-05 - val_loss: 1.0358e-04
# Epoch 36/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 2.6047e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_36.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 2.5983e-05 - val_loss: 1.3436e-04
# Epoch 37/50
# 1831/1831 [==============================] - ETA: 0s - loss: 2.1331e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_37.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 2.1331e-05 - val_loss: 1.0207e-04
# Epoch 38/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 2.0328e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_38.model/assets
# 1831/1831 [==============================] - 16s 9ms/step - loss: 2.0289e-05 - val_loss: 1.2694e-04
# Epoch 39/50
# 1828/1831 [============================>.] - ETA: 0s - loss: 1.9482e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_39.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 1.9458e-05 - val_loss: 8.5942e-05
# Epoch 40/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 1.9785e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_40.model/assets
# 1831/1831 [==============================] - 13s 7ms/step - loss: 1.9730e-05 - val_loss: 1.6431e-04
# Epoch 41/50
# 1831/1831 [==============================] - ETA: 0s - loss: 1.9352e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_41.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 1.9352e-05 - val_loss: 9.2825e-05
# Epoch 42/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 1.7340e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_42.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 1.7326e-05 - val_loss: 1.0247e-04
# Epoch 43/50
# 1825/1831 [============================>.] - ETA: 0s - loss: 1.6050e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_43.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 1.6030e-05 - val_loss: 6.0944e-05
# Epoch 44/50
# 1829/1831 [============================>.] - ETA: 0s - loss: 1.5737e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_44.model/assets
# 1831/1831 [==============================] - 16s 9ms/step - loss: 1.5751e-05 - val_loss: 1.0364e-04
# Epoch 45/50
# 1824/1831 [============================>.] - ETA: 0s - loss: 1.7009e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_45.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 1.7073e-05 - val_loss: 1.4884e-04
# Epoch 46/50
# 1827/1831 [============================>.] - ETA: 0s - loss: 1.4640e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_46.model/assets
# 1831/1831 [==============================] - 14s 8ms/step - loss: 1.4625e-05 - val_loss: 6.2228e-05
# Epoch 47/50
# 1826/1831 [============================>.] - ETA: 0s - loss: 1.5221e-05INFO:tensorflow:Assets written to: models/emd_RNN_weekly_valid_47.model/assets
# 1831/1831 [==============================] - 14s 7ms/step - loss: 1.5226e-05 - val_loss: 1.2077e-04
# Epoch 48/50
# 1118/1831 [=================>............] - ETA: 4s - loss: 1.3502e-05

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'emd_RNN_weekly_valid_46'

# %%
# Save best model to Drive
emd_RNN_weekly_model = load_model(f'models/{best_model}.model')
emd_RNN_weekly_model.save(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
emd_fc = emd_RNN_weekly_model.predict(emd_valid_shaped)

# %%
# Rescale forecasted values
emd_rescaled = emd_scaler.inverse_transform(emd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/emd_RNN_weekly_valid.npy', emd_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
emd_RNN_weekly_model = load_model(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
emd_fc = emd_RNN_weekly_model.predict(emd_test_shaped)

# %%
# Rescale forecasted values
emd_rescaled = emd_scaler.inverse_transform(emd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/emd_RNN_weekly_test.npy', emd_rescaled.flatten())

# %% [markdown]
# ###on VMD corn weekly

# %%
# Set checkpoint callback
filepath = 'vmd_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
VMDregressor = define_vmd_model()

# Train model
with tf.device('/device:GPU:0'):
  VMDregressor.fit(vmd_train_shaped,
                   epochs=decomp_EPOCHS,
                   validation_data=vmd_valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 0.0047INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_01.model/assets
# 1830/1830 [==============================] - 32s 17ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 2/50
# 1830/1830 [==============================] - ETA: 0s - loss: 4.5485e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_02.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 4.5485e-04 - val_loss: 0.0153
# Epoch 3/50
# 1830/1830 [==============================] - ETA: 0s - loss: 3.7816e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_03.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 3.7816e-04 - val_loss: 0.0040
# Epoch 4/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 3.2442e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_04.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 3.2378e-04 - val_loss: 0.0032
# Epoch 5/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.7396e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_05.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 2.7399e-04 - val_loss: 0.0070
# Epoch 6/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 2.4184e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_06.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 2.4176e-04 - val_loss: 0.0073
# Epoch 7/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.0416e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_07.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 2.0436e-04 - val_loss: 0.0011
# Epoch 8/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.8374e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_08.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 1.8377e-04 - val_loss: 0.0017
# Epoch 9/50
# 1830/1830 [==============================] - ETA: 0s - loss: 1.6636e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_09.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.6636e-04 - val_loss: 0.0017
# Epoch 10/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.5583e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_10.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.5617e-04 - val_loss: 4.6926e-04
# Epoch 11/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.2174e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_11.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 1.2168e-04 - val_loss: 3.1713e-04
# Epoch 12/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.1454e-04INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_12.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.1436e-04 - val_loss: 0.0014
# Epoch 13/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 9.8315e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_13.model/assets
# 1830/1830 [==============================] - 27s 14ms/step - loss: 9.9298e-05 - val_loss: 8.3001e-04
# Epoch 14/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 9.4107e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_14.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 9.4038e-05 - val_loss: 5.0256e-04
# Epoch 15/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 9.3040e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_15.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 9.3039e-05 - val_loss: 5.8359e-04
# Epoch 16/50
# 1830/1830 [==============================] - ETA: 0s - loss: 8.3692e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_16.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 8.3692e-05 - val_loss: 1.8847e-04
# Epoch 17/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 6.6473e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_17.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 6.6417e-05 - val_loss: 9.9875e-04
# Epoch 18/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 4.0811e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_18.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 4.0828e-05 - val_loss: 9.2417e-05
# Epoch 19/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 2.0247e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_19.model/assets
# 1830/1830 [==============================] - 27s 14ms/step - loss: 2.0300e-05 - val_loss: 1.4952e-04
# Epoch 20/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 3.3631e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_20.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 3.3584e-05 - val_loss: 6.0364e-05
# Epoch 21/50
# 1830/1830 [==============================] - ETA: 0s - loss: 1.7278e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_21.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.7278e-05 - val_loss: 4.6842e-05
# Epoch 22/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 2.4497e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_22.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 2.4472e-05 - val_loss: 6.5756e-05
# Epoch 23/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.5467e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_23.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 1.5458e-05 - val_loss: 4.2621e-05
# Epoch 24/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.5794e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_24.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 1.5775e-05 - val_loss: 4.0904e-04
# Epoch 25/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.4545e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_25.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.4530e-05 - val_loss: 3.1442e-05
# Epoch 26/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.2945e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_26.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 1.2945e-05 - val_loss: 1.9865e-04
# Epoch 27/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.8766e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_27.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 1.8750e-05 - val_loss: 4.1495e-05
# Epoch 28/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.2415e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_28.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.2410e-05 - val_loss: 1.4301e-04
# Epoch 29/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.2446e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_29.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 1.2466e-05 - val_loss: 5.7639e-05
# Epoch 30/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.0722e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_30.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.0704e-05 - val_loss: 4.6439e-05
# Epoch 31/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 2.0793e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_31.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 2.0784e-05 - val_loss: 3.2072e-05
# Epoch 32/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.3129e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_32.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.3157e-05 - val_loss: 2.6809e-05
# Epoch 33/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.2656e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_33.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.2646e-05 - val_loss: 4.6190e-05
# Epoch 34/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 2.2007e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_34.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 2.1984e-05 - val_loss: 3.3313e-05
# Epoch 35/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.0577e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_35.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.0590e-05 - val_loss: 1.0797e-04
# Epoch 36/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.2694e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_36.model/assets
# 1830/1830 [==============================] - 25s 14ms/step - loss: 1.2701e-05 - val_loss: 2.0271e-04
# Epoch 37/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.1012e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_37.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.1041e-05 - val_loss: 4.2628e-05
# Epoch 38/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 2.7730e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_38.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 2.7690e-05 - val_loss: 2.1459e-05
# Epoch 39/50
# 1826/1830 [============================>.] - ETA: 0s - loss: 1.1494e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_39.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.1525e-05 - val_loss: 4.0052e-05
# Epoch 40/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.1932e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_40.model/assets
# 1830/1830 [==============================] - 24s 13ms/step - loss: 1.1930e-05 - val_loss: 3.2659e-04
# Epoch 41/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.2995e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_41.model/assets
# 1830/1830 [==============================] - 25s 13ms/step - loss: 1.2979e-05 - val_loss: 3.9514e-05
# Epoch 42/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.3387e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_42.model/assets
# 1830/1830 [==============================] - 26s 14ms/step - loss: 1.3393e-05 - val_loss: 2.2855e-04
# Epoch 43/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.1507e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_43.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.1504e-05 - val_loss: 3.9456e-05
# Epoch 44/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.1772e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_44.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.1766e-05 - val_loss: 6.9196e-05
# Epoch 45/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 2.7281e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_45.model/assets
# 1830/1830 [==============================] - 29s 16ms/step - loss: 2.7264e-05 - val_loss: 4.8583e-05
# Epoch 46/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 9.9660e-06INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_46.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 9.9553e-06 - val_loss: 5.0444e-05
# Epoch 47/50
# 1827/1830 [============================>.] - ETA: 0s - loss: 1.2656e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_47.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.2640e-05 - val_loss: 3.5495e-05
# Epoch 48/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.5450e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_48.model/assets
# 1830/1830 [==============================] - 30s 16ms/step - loss: 1.5442e-05 - val_loss: 3.3285e-05
# Epoch 49/50
# 1828/1830 [============================>.] - ETA: 0s - loss: 1.1090e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_49.model/assets
# 1830/1830 [==============================] - 28s 15ms/step - loss: 1.1097e-05 - val_loss: 4.1494e-05
# Epoch 50/50
# 1829/1830 [============================>.] - ETA: 0s - loss: 1.3658e-05INFO:tensorflow:Assets written to: models/vmd_RNN_weekly_valid_50.model/assets
# 1830/1830 [==============================] - 27s 15ms/step - loss: 1.3651e-05 - val_loss: 4.5352e-05

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'vmd_RNN_weekly_valid_38'

# %%
# Save best model to Drive
vmd_RNN_weekly_model = load_model(f'models/{best_model}.model')
vmd_RNN_weekly_model.save(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
vmd_fc = vmd_RNN_weekly_model.predict(vmd_valid_shaped)

# %%
# Rescale forecasted values
vmd_rescaled = vmd_scaler.inverse_transform(vmd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/vmd_RNN_weekly_valid.npy', vmd_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
vmd_RNN_weekly_model = load_model(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
vmd_fc = vmd_RNN_weekly_model.predict(vmd_test_shaped)

# %%
# Rescale forecasted values
vmd_rescaled = vmd_scaler.inverse_transform(vmd_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/vmd_RNN_weekly_test.npy', vmd_rescaled.flatten())

# %% [markdown]
# ## on non-decomposed

# %%
# Set checkpoint callback
filepath = 'true_RNN_weekly_valid_{epoch:02d}'
checkpoint = ModelCheckpoint('models/{}.model'.format(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'))

# Define model
TRUEregressor = define_non_decomp_model()

# Train model
with tf.device('/device:GPU:0'):
  TRUEregressor.fit(train_shaped,
                   epochs=non_decomp_EPOCHS,
                   validation_data=valid_shaped,
                   callbacks=[checkpoint])
# Out:
# Epoch 1/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 0.0037INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_01.model/assets
# 1830/1830 [==============================] - 16s 8ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 2/8
# 1830/1830 [==============================] - ETA: 0s - loss: 4.9828e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_02.model/assets
# 1830/1830 [==============================] - 14s 8ms/step - loss: 4.9828e-04 - val_loss: 0.0024
# Epoch 3/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 4.1442e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_03.model/assets
# 1830/1830 [==============================] - 13s 7ms/step - loss: 4.1320e-04 - val_loss: 0.0019
# Epoch 4/8
# 1825/1830 [============================>.] - ETA: 0s - loss: 3.7974e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_04.model/assets
# 1830/1830 [==============================] - 14s 8ms/step - loss: 3.8013e-04 - val_loss: 0.0019
# Epoch 5/8
# 1823/1830 [============================>.] - ETA: 0s - loss: 3.5200e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_05.model/assets
# 1830/1830 [==============================] - 14s 7ms/step - loss: 3.5166e-04 - val_loss: 0.0019
# Epoch 6/8
# 1824/1830 [============================>.] - ETA: 0s - loss: 3.2393e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_06.model/assets
# 1830/1830 [==============================] - 13s 7ms/step - loss: 3.2345e-04 - val_loss: 0.0033
# Epoch 7/8
# 1826/1830 [============================>.] - ETA: 0s - loss: 3.1336e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_07.model/assets
# 1830/1830 [==============================] - 14s 8ms/step - loss: 3.1290e-04 - val_loss: 0.0026
# Epoch 8/8
# 1822/1830 [============================>.] - ETA: 0s - loss: 3.0900e-04INFO:tensorflow:Assets written to: models/true_RNN_weekly_valid_08.model/assets
# 1830/1830 [==============================] - 14s 7ms/step - loss: 3.0816e-04 - val_loss: 0.0038

# %%
## ACTION REQUIRED ##

# Select best model by lowest validation loss
best_model = 'true_RNN_weekly_valid_05'

# %%
# Save best model to Drive
true_RNN_weekly_model = load_model(f'models/{best_model}.model')
true_RNN_weekly_model.save(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd validation set forecasts
true_fc = true_RNN_weekly_model.predict(valid_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/true_RNN_weekly_valid.npy', true_rescaled.flatten())

# %%
#### TEST SET ####

# %%
# Load the model
true_RNN_weekly_model = load_model(f'/content/gdrive/My Drive/models/{best_model}.h5')

# %%
# Use best model to generate emd test set forecasts
true_fc = true_RNN_weekly_model.predict(test_shaped)

# %%
# Rescale forecasted values
true_rescaled = true_scaler.inverse_transform(true_fc)

# %%
# Save emd validation set predictions
np.save('/content/gdrive/My Drive/outputs/true_RNN_weekly_test.npy', true_rescaled.flatten())

# %% [markdown]
# # End
